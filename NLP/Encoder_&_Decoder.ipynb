# %%
import numpy as np
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
from keras.layers import Dense, Input, LSTM, Embedding
from keras.models import Model
from string import digits
from sklearn.model_selection import train_test_split

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/Hindi_English_Truncated_Corpus.csv')

# %%
df.head()
# Out:
#       source  ...                                     hindi_sentence
# 0        ted  ...  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1        ted  ...  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2  indic2012  ...   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3        ted  ...     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4  indic2012  ...        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।
#
# [5 rows x 3 columns]

# %%
df.shape
# Out:
# (127607, 3)

# %%
pd.isnull(df).sum()
# Out:
# source              0
# english_sentence    2
# hindi_sentence      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# source              0
# english_sentence    0
# hindi_sentence      0
# dtype: int64

# %%
df = df.sample(n=25000, random_state=42)

# %%
Lemmatizer = WordNetLemmatizer()

# %%
def preprocessing_text(df):
    processed_text = list()
    lines = df['english_sentence'].values.tolist()
    for i in lines:
        text = i.lower()
        pattern = re.compile('http[s]?://(?:[A-Za-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub("", text)
        text = re.sub(r"[,.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
        text = re.sub(r'[^a-zA-Z]', ' ', text)
        tokens = nltk.word_tokenize(text)
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        words = [word for word in stripped if word.isalpha()]
#         stop_word = set(stopwords.words('english'))
#         stop_word.discard("not")
        words = [nltk.WordNetLemmatizer().lemmatize(w) for w in words]
        words = ' '.join(words)
        processed_text.append(words)
    return(processed_text)
english_sentenced_text = preprocessing_text(df)

# %%
english_sentenced_text
# Out:
# ['islam is word from arabic and it full word is salamaits definition peace surrender',
#  'everything is reliant on these computer working',
#  'parliament doe not control the government',
#  'race equality new law',
#  'the provision would not affect the power of parliament to make law in respect of income from profession etc lrb article rrb',
#  'from the top of the adhishthana at about the middle of the northern side an immense and carved waterspout is projected which discharge the abhisheka water flowing out of the sanctum floor',
#  'there wa lasagna there wa casserole',
#  'super power india source google writer vedpratap vedik',
#  'each wa a blow to conservatism',
#  'if he is satisfied that the matter is urgent and of sufficient importance to be raised in the house at an early date and an early opportunity is otherwise not available for discussing the matter he may admit the notice',
#  'the colour of the drake is black at the neck and back',
#  'in the mathare valley slum',
#  'the second time wa a procedure that involved local anesthesia',
#  'uttarpradesh a mirrorlive hindustan',
#  'this can download any medium and play it or can be synchronized with any external medium player too',
#  'to make sure that just coming into the laboratory',
#  'let me give you a couple of example',
#  'an expert in the plant of mesoamerica sandy knapp ha been working with scientist in the missouri botanic garden and the institute of biology of the universidad nacional autnoma de mxico',
#  'why don t you teach them not to waste money',
#  'the other two member will have knowledge and experience of special educational need',
#  'okay sam why do you do this sort of thing',
#  'step inside of the tiny little world',
#  'help them to notice the spelling of common word lrb because many rrb and encourage them to look at word check and remember how word that they use often are spelt',
#  'wa poetry no more than this amusing exercise',
#  'the rectangle is more common for the mandapas and gopuras which are called padippura',
#  'in uncertainty future temperature and total world different part of hot and related change involvedmost national govt kyoto protocol are sighned',
#  'and i m going to show you example of these puzzle momentarily',
#  'the source of such debt are bizarre',
#  'he spent year in indonesia from the age of to with his indonesian mother and his step father',
#  'step to remove the parallel system of jurisdiction the first attempt to bridge the gulf between these two system wa made in when by an act of parliament the company s court were vested with civil jurisdiction over the european in suit brought against them by indian',
#  'and it seems like year ago',
#  'step after the tooth is anesthetized an opening is made through the crown into the pulp chamber',
#  'my dollar usually go to a good cause',
#  'the craziest thing wa i d never seen any of that before except bread',
#  'according to tradition to broke the wall make a way in durg and silently his death body is buried in mausoleum of sikandara',
#  'bhelpuri a popular chat masala',
#  'she run two of the line and ha already saved enough money',
#  'soft power is a concept invented by a harvard academic',
#  'that said stop',
#  'the chief wildlife warden of the state b majumdar say the main problem lie in the unprotected forest area that account for per cent of the state s total forest area and are home to almost per cent of it wildlife',
#  'woman because we re on the ground we know the tradition',
#  'if merchant shipping were to be considered a the fourth arm of the army a it should in time of war coordinated development of the navy and the mercantile marine wa called for',
#  'however well a bowler may spin the ball however fast he may bowl unless his ball ha length and direction it will not get him a wicket and will be hit all over the field',
#  'you can not get protection if your benefit stopped because of a medical test',
#  'they are helpful for some time state history and cultural and political reason whether in one particular matter member in terrorism',
#  'without that they could not have played any effective part in the building up of indian nationalism of the new type and they would have been doomed to play second fiddle to the hindu with their better education and far stronger economic position',
#  'in our world at the moment',
#  'in accordance with the theory of guru vallab and the change made by leela',
#  'torat which provided to musa',
#  'chief typepad',
#  'the more we understand life and nature the le we look for supernatural cause',
#  'there s a point you can stand here',
#  'politics',
#  'yatrasunday',
#  'to transfer the circulation of the motor',
#  'breast milk provides exactly the right nutrient growth factor hormone and immunity a young baby need to grow and develop',
#  'a walking talking faculty meetingattending zombie back home',
#  'muthubhood indological research institutetantra and augmented study',
#  'it is also essential that a new social and cultural fabric be inducted into the society',
#  'this ha been proved which is a magic',
#  'what the structure of spacetime itself is doing during this period',
#  'and these thing have all been related spatially',
#  'it is therefore with the temper and approach of science allied to philosophy and with reverence for all that lie beyond that we must face life',
#  'in defense of freedom of speech',
#  'but in another vachana he ha said that he wa made to feel poorer by not being asked for gift and that he wa prepared to give away even the treasury if asked for',
#  'some stay it a baluchi',
#  'in general there is an agreement amongst research worker that more damagedaltered dna is found in older animal',
#  'extracellular matrix from pig',
#  'the extremist who were also known a the nationalist formed a very distinct group',
#  'firefox extension useful for hindi',
#  'for repeated transfusion of rh positive blood in a negative person of either sex may eventually produce serious adverse reaction',
#  'in south india there are lot of durga idol of which most are present in the sea shore',
#  'according to a national radio program due to this the threat of disease is greatly reduced which reduces the extent to which an epedemic might occur',
#  'is probably the most important of all of these',
#  'that confirms our belief',
#  'it is worth recalling how this novel came to be written',
#  'and only by paying attention to these thing',
#  'at one point the police advised the family to contact the procurator fiscal themselves',
#  'i want to point out that it is historically false to say that europe and asia should not be at peace with one another',
#  'one belief this is the one and only life',
#  'with the pink polka dot',
#  'there is terminal end of urinary route on the tip of glans penis which is called penile urethra',
#  'effect of ramayana on various culture and civilization in pdf format',
#  'the constituent assembly accomplished the tremendous task of framing the constitution in le than three year',
#  'training for a professional or specialist qualification',
#  'when the global temperature increase the the ice at the pole start melting faster',
#  'several reader were taken in by this hoax and rabindranath ha told u in his reminiscence how a bengali scholar dr nishikanta chatterjee who wa in germany when the issue of bharati in which these lyric appeared reached him wa so impressed by them that in his book on the lyrical poetry of india published in german he gave a very high place to this th century poet bhanu singh',
#  'category hindi prosewriter',
#  'in the civilized world',
#  'because we d never done this before and they didn t know exactly how to do it',
#  'ariel merari terrorism a plan in terrorism political violence in the form of terrorism volume no winter pp',
#  'the mountain midge occur on the northwest himalaya tien shan altai in korea kamchatka the canadian rockies and on the rockies of the united state of america',
#  'it provides an insight into the situation a it developed from war boom to postwar depression the transient recovery the great depression and the slow recovery thereafter till the shadow of another world catastrophe wa lengthening across the indian scene',
#  'a though we can curl up with it on a rainy afternoon',
#  'the record of highest run in the test cricket',
#  'geetanjali in english',
#  'of the apps that the fellow wrote last year',
#  'the supplementary demand for grant are presented to and passed by the house before the end of the financial year while the demand for excess grant are made after the expenditure ha actually been incurred and after the financial year to which it relates ha expired',
#  'akra kay human rule',
#  'sulfur oxide sox mainly sulfur dioxide emits from the burning of coal and oil',
#  'terrorism is vary largely used by political organization for fulfill these aiming in the presence of both west wing and left wing political party nationalistic religious group revolutionary and current government make a law of war for related to armed struggle actor dispute',
#  'what other property of language doe the script show',
#  'then it would accelerate in this direction',
#  'i ve spent the last five year of my life',
#  'the main symptom are rise in temperature discharge from the nose and eye cough pneumonia pleurisy and inflammation of joint especially of hind limb',
#  'we may be moving into yet another economic form',
#  'category south jamboodweep',
#  'the rehabilitation work in rural area ha earned the gujarat government the admiration of many foreign agency involved in rebuilding the state',
#  'it wa a majestic phase which had begun and ended splendidly',
#  'nazi migration in germany and meet hitler',
#  'i wa groomed a an entrepreneur',
#  'and this student probably the first time using it',
#  'by law you are responsible for making sure that your child are educated between the age of and',
#  'most of indian industry is in deep recession with sale and profit falling between april and december',
#  'indian movie studio bollywood is also present in mumbai only',
#  'construction work is about to begin on the plot allotted to gujarat s minister of state for urban development parmanand khattar and former bjp mp haribhai patel',
#  'the climax of ramalinga s dissatisfaction with the running of the sabhai or temple wa reached in his deciding to close it down in',
#  'applause',
#  'the ewe yield appreciable quantity of milk',
#  'where a roof that doe not leak is a luxury but a telephone is a must because that s how the next job come by',
#  '',
#  'grows into an oak tree',
#  'quite a few tribe have special ceremony related to them',
#  'to continue putting polluting facility in my neighborhood',
#  'karna wa interested in the art of war and hence he took training under parashuram when dronacharya refused to teach him',
#  'simple language is natural and full of sur agaidigdh',
#  'a a result during the bloodshed in anglonepal war took place in which nepal had to forgo one third territory but it maintained it self respect and independence',
#  'any street in california',
#  'we know that scientifically',
#  'akregator akregator editing computing mean feeder akregator in computerit is called feed readernews reader or general akregatorthis is a desktop or web application which is anthology available on internet like news headlinesblogpodcast and blog in one place and publish this',
#  'and why your unicorn defense are working just great',
#  'but dialogue have led u nowhere because they do n t want the return of benazir',
#  'voice speech from text sound tt',
#  'of course it s a very shorttermist strategy it s a losing battle',
#  'they will guarantee a troubled succession',
#  'premchant do many experiment to achieve the top of art',
#  'when you meet someone here at ted',
#  'but it wasn t always like that',
#  'through his welfare measure he drew indian muslim also towards him',
#  'in the beginning of the th century the french missionary of pondicherry were interested in these island',
#  'each navaranga ha three projected entrance in a cruciform manner with the northern arm of the southern navaranga joined to the southern arm of the northern navaranga resulting in a common passage between the two',
#  'selling a car with a false mileage is illegal',
#  'from the treasury to the judiciary and from cm to dm she stood for personalised autarchy',
#  'netaji received congratulation from eamon de velera president of the irish free state',
#  'that s very good news because i thought that wa what the answer would be',
#  'thus while uttar pradesh ha member in the rajya sabha smaller state like manipur mizoram sikkim tripura etc have only one member each',
#  'for a country of this small size the geographical variation are astonishing',
#  'in the sky above you all the time',
#  'the first plenary session elected a number of commission',
#  'these kumbha panjaras became a common feature',
#  'the gestation period in female varies from to month',
#  'he died after narrating all thing and after doing funeral of jatayu ram went inside the sadhan forest for the search of sita',
#  'and i think this wa possible thanks to the building block',
#  'but if i walk shouldertoshoulder',
#  'if the balance in an individual s saving account exceeds a specified amount the excess cash flow into an fd that offer a higher rate of interest',
#  'this elevated area divide the garden into row made at a lower level',
#  'the immigration rule require a person who is to take employment for which a work permit is needed to have a permit before entering the country',
#  'while mining and quarrying registered a higher growth rate than in the fifth plan the electricity and manufacturing sector had lower growth rate than in the fifth plan',
#  'on the rooftop with my friend',
#  'category city',
#  'especially when it s degree out',
#  'including my mother and father',
#  'in absence of akbar hemu vikramaditaya is attack the delhi and aagra and got win',
#  'with any halfway decent meritocratic idea',
#  'and tesla would all be probably diagnosed',
#  'it declined to per cent in',
#  'that we do here in the u',
#  'this invaluable tool of the english language fell into badruddin s hand when he went to school in england',
#  'chennai they may be used to sniffing around but the ban on smoking in public place ha given the chennai police more of that to do',
#  'city of likampur kheri',
#  'it wa chic to be left wear kurta and sport angst a an unshaven commitment',
#  'pandit jawaharlal nehru remained neutral and remained alone with sahardbabu subahashbabu',
#  'the clumping reaction between antibody of the mother and the red cell of her unborn child provokes anaemia',
#  'while the latter had cordial meeting with the prime minister and the home minister basu painted the capital red literally by sitting in dharna in the parliament complex pushing for the elusive third front and playing his old number about the bjp leadership being uncivilised and barbaric time and again',
#  'if you meet someone at the bottom of society',
#  'but these objector were overwhelmed by the mass sentiment the congress had created and hardly ever gave public expression to their view',
#  'padmalaya telefilm a hyderabadbased feature film studio is now translating the ancient tale supposedly written by pandit vishnu sharma to educate recalcitrant prince into a multicrore animation series in association with film club usa',
#  'and this is the africa where people are looking for partnership',
#  'that granted telecom immunity for possibly warrantless spying',
#  'and to start with secondly',
#  'sonmanthru nagar',
#  'the wheel of fate will one day compel the british to give up their indian empire',
#  'this one s clever it s called obsidian',
#  'in the th century many part of it were damaged by some robber and attacker',
#  'so evidence against our model',
#  'meaning of ejection is getting out of the semen from the penis and commonly associated with the pleasure of intercourse',
#  'any one of you could be famous on the internet',
#  'one wa the islam club at chowpatty where muslim of all sect congregated and got to know each other',
#  'and the hunt point riverside park became the first waterfront park',
#  'the central government ha the power to change the name of the state their area and limit without any authorization from the stateessay the state are an integral part of the indian union',
#  'and in the information era we all live in today',
#  'in order to age more slowly',
#  'here one telephone service is available for each personswired service is available in whole country but most centralized on city and district headquartersfor increase reach of people to service mobilewirelessservice facility is too good in whole country',
#  'it consists of many closelypacked rod made of mineral',
#  'there are atleast four genetic disorder in human being that are characterised by sign of premature aging',
#  'in the farmland of gujarat there is a fullfledged genetic battle raging',
#  'how do i appeal against a decision',
#  'limited company having shareholder own a large number of industry',
#  'she grew up on a farm in austria very poor',
#  'even now during dark night malay boat visit these shore with smuggled good',
#  'class river of bihar',
#  'albiruni doe not give any particular about him except that he wa the author of a treatise on buddhism which eranshahri lrb no above rrb had incorporated in his own book',
#  'now in order for u to really chew on information',
#  'after the second world war in july britain announced it new policy regarding india and sent three official to india with the purpose of forming a committee for forming the constitution',
#  'without any dry land in the beginnig the total area of the top surface of the ocean ha been growing gradually during the last billion year for example the total size of the continent',
#  'in the ganga golden jubilee museum there is a big collection of earthen pot painting carpet coin and weaponry',
#  'you remember the space race in the s wa for national prestige',
#  'during the decade export increased from lakh ton to nearly a million ton',
#  'chawla held a certificated flight instructor rating for airplane glider and commercial pilot license for single and multiengine airplane seaplane and glider',
#  'badruddin came home to india for a year in although with his father gone and his mother on her deathbed it wa a sad homecoming',
#  'and build bigger and bigger component',
#  'the pressure is gradually released and the person taking blood pressure measurement in the gauge will listen through the stethoscope for the sound of the pulse in the artery',
#  'this can cause crowding or displacement of other teeth or lead to the development of localized tooth decay infection or gum disease',
#  'we can use online and can even be downloaded',
#  'a locust is essentially a grasshopper that is capable of becoming gregarious and migratory in regular alternating cycle',
#  'every single thing i planned to say they have said it here',
#  'besides he is empowered to decide after obtaining the opinion of the election commission whether any member duly elected attracts the disqualification laid down in art of the constitution',
#  'it a kind of prayer taken in arabic language with a special restriction',
#  'he had said my idea of nationalism is that my country may become free that if need be the whole of the country may die so that the human race may live',
#  'is a father who recognizes the value in his daughter',
#  'by thinking big the architect of the temple of modern india unwittingly provided for future golden handshake',
#  'so there is only so much one can do',
#  'the south bronx which lie in between did not stand a chance',
#  'down to a down to g down to f',
#  'in this a four river flow in four directionstowards northsoutheast and west from a central mountain or fountain that divide the garden in four part',
#  'garud puran garud mean eagle',
#  'during this the lonelinessworkworshipknowledge devotional ha been discussed very well',
#  'this phone directly run with a artificial satellite which connect with base station and other satellite one satellite produce more than base station',
#  'public court public court are separated from these regular court ex officio or retired judge and two social worker there is a trial lawyer sadshy it only be used when both party accept it a these insurance claim recovery dealt with promise to give',
#  'the foreign government might if defeated abandon the country to it fate but the people and it leader can not adopt that callous attitude',
#  'late shri gv mavalankar the first speaker of indian parliament held that the committee on subordinate legislation is the custodian of the duty of parliament and keep the administration within bound intended by parliament',
#  'but for a life jacket',
#  'seeing god wa great happiness and union with him wa great ecstasy he exclaimed',
#  'the congress called upon the people to observe a total hartal on the day scheduled for the prince s landing in bombay',
#  'what is relevant to our present purpose is the fact that the living substance which carry heredity resides solely in the nucleus of the daughter cell at the end of each miotic division of it parent',
#  'in our country the punjab and sind had the closest relation with the muslim king and kingdom',
#  'would this guy have like a blue uniform',
#  'total eleven time in his life subhash babu got the imprisonment',
#  'milali wa cruising majestically along the west coast towards flat island and we were now in the jarawa area',
#  'thanks a lot',
#  'and what happens',
#  'and even if there is no eclipse at such a time it is considered quite a propitious a the time of an eclipse itself',
#  'however the province were to have an option to accept or walk out of the new constitution',
#  'he agreed to set up a committee to modify the bill to try and make it a model for all district local board throughout the country',
#  'then also it is being said that there is doubt in it success',
#  'both of them became alert on hearing warning from datta',
#  'it would be facile to dismiss the violence in kathmandu over hrithik roshan s alleged antinepalese remark a merely a bad joke gone wrong',
#  'more than one run can be made on one hit in one hit one to three rune are common the shape of ground is in this way that more that four run can t be made to fill this disadvantage if ball hit the outside land of boundary that it is counted a four run and if ball cross the boundary directly from air then it is counted a six run if ball cross the boundary then there is no need to run for the batsman',
#  'however contrary to what planner had hoped instead of settling down in gandhinagar many among the high and mighty misused the scheme and made million by selling the plot to builder at hefty premium',
#  'by an incredible entrepreneur named patrick henfrey and his three colleague',
#  'the amount are similar to those paid for jury service',
#  'riding on the face the full pleasure of the cowgirl position and the beginning of the control start from this position this is basically a position for oral sex in this the man lie down stright on his back and the woman with the support of her knee brings her cunt area onto the top of the face of the man this is liked very much because the control is with the woman and she can change her focus by moving back and forth for more pressure she can move a bit down and get the pleasure of increase in excitement rodeo this is the reverse of the horse riding positionin this the man can see the backside portion of the woman and there is some difficulty in reaching her breast etc those having difficulty to slide in the horse riding position for them this is the right positio for gspot friction even so in this positon the spot can be rubbed in many way and the man get a fair portion of the act of penetration in this the man lie down on his back and the woman keeping her seat towards his face come on to the top of his prick on her knee and get the entry done she give support to her body by propping her hand in the man s palm because of this in this position intense and easy intercourse is achieved',
#  'in the ancient dynasty of india mourya kinddom of north india is mentionable whose great emperor ashoka ha a special place in world history',
#  'but they came up with a book',
#  'siddharth gautam bc wa a prince of shakya dynasty who lived the life of a saint after leaving his kingdom and he became buddha',
#  'not afraid of problem he always moved from village to village and showed his love for the country and countryman which is remembered a his duty',
#  'worship period',
#  'the jurisdiction of a high court may be extended to or excluded from a union territory lrb article rrb',
#  'likewise if a nuclear entity like an electron is a discrete particle it is also a wave diffused over a continuum',
#  'no other national leader except nehru shared that concern',
#  'because this is really a transformation of the ecosystem a a whole',
#  'in other word you re certainly fastforwarding this whole process',
#  'through their socalled propaganda or mainstream medium',
#  'the chargesheet of inefficiency against this ministry run into ream',
#  'the northern ratha of the twin pidari rathas facing north with it ardhamandapa is of the pure nagara order with only this difference that there is no hara over the second talaan advanced featuremaking it out a the last of the series in mahabalipuram and anticipating in this respect the later vimanas of the eighth century',
#  'and the gag is',
#  'marathi food cuisine',
#  'other two are agra fort and fatehpur sikri',
#  'what is a dhamma immoral is per budhha',
#  'and until about a few year ago',
#  'if thing are not put right straight away collect evidence about the problem such a photograph statement from other holiday maker',
#  'submit it to reddit and the community of your peer',
#  'so that we can grow up to blow you away',
#  'that doe not value these quality',
#  'first phase march',
#  'we thus observe that mendel s second law provides an opportunity for bringing together gene which have arisen separately',
#  'hit the ball twice hit the ball twice this is a very abnormal and is started keeping in mind the risk and safety of the player of the fielding side the batsman after legally hitting the ball once he can only hit the ball the second time to stop the ball from going on to hit the stump',
#  'tyre poetic feature',
#  'he further argued that brahnwnism preached only karma and not bhakti',
#  'i took the responsibility upon myself and i telegraphed to stop all further agitation',
#  'healthy building for u',
#  'abdul rahim khan e khana wa a poet and wa the son of akbar s guard bairam khan',
#  'in what we would say to be friendly gesture',
#  'that s a guess',
#  'he read with him select piece from sanskrit bengali and english literature and in the evening made him sit by his side and sing his favourite hymn',
#  'the messenger of god that have since continuously arrived on earth for thousand of year no matter which place they appear they preached the same thing they had one goal to teach humanity to lead a life a god had decreed',
#  'four year ago when he became the congress president the moment should have been the logical culmination of a career steeped in eternal virtue of the most obedient congressman',
#  'who would be willing to take a risk on building a new technology',
#  'in the land where gandhiji went',
#  'this he could do by training troupe of actor and dancer who would stage his play and ballet in different town and help to raise money',
#  'that we think are related to coherence',
#  'united state of america',
#  'this ha more than quadrupled the atm reach of these bank',
#  'because we can redraw our original diagram this way',
#  'seventh schedule in the constitution divide the topic of legislation between center and state government union is the most important topic in the list',
#  'he pasted up portrait all over his reservation',
#  'but if there is one dominant emotion in modern society that is envy',
#  'after playing supporting actor in film roti kapda aur makaan he did many guest appearance like in kuvara baap aur dost',
#  'the industry particularly the bombay mill however can not be absolved of the charge of mismanagement financial imprudence and a general lack of enterprise',
#  'in the nonregulation province the local government wa empowered to invest the deputy commissioner or other chief executive officer of the district with power to try a a magistrate all offence not punishable with death and to pas sentence of imprisonment for a term not exceeding seven year',
#  'in th october radio telephone america petrate office by this copper released it later anerica petrate released',
#  'indeed it is playing into the hand of the government',
#  'a certain latitude wa allowed for various type to develop so that with greater experience particular type might be encouraged more than others',
#  'is reckless and abusive',
#  'heaven poisonfighting development and terrorism srilanka war by john richardson',
#  'in islam god ha been considered superior to the understanding of man',
#  'the literature of sanskrit is very old large and varied',
#  'so the best way i ve found of trying to get people',
#  'on july th',
#  'it s capital is islamabad and other major city are karachi and lahore',
#  'indian government s ministry of nonconventional energy source encouraging solar lantern solarhome solar public lighting system waterpump also for area from village development of photo voltage energy dependent equipment and their instalment etc',
#  'in india the cock of this breed have proved useful for upgrading the ordinary desi hen',
#  'which led me to come to this point',
#  'if it had it might have understood that the main reason why economic reform have not been supported by ordinary indian is that they have till now affected only the life of big businessmen and foreign investor',
#  'two significant trial were held in the red fort of delhi',
#  'to the orthodox hindu the shankaracharya occupies one of the most revered seat in the faith',
#  'this provided an opportunity to our equipment manufacturer to develop expertise for the fabrication of many sophisticated item',
#  'than we are about insect a indeed we are',
#  'actually near afghanistan',
#  'so obiang junior well he buy himself',
#  'section bothered by noise',
#  'most elementary solution to a problem that wa possible',
#  'mobile phone',
#  'there s a doubling of this jarshaped sign',
#  'inside a house handed over to a villager two year ago shankar padsalgi the wizened sarpanch of killari us his walking stick to tap out chunk of plaster',
#  'if you can not get smp or ma',
#  'growing up a a boy we were taught',
#  'run out a member of the fielding side ha broken or put down the wicket with the ball while a batsman wa out of his ground this usually occurs by mean of an accurate throw to the wicket while the batsman are attempting a run',
#  'hindu in government service had started learning persian during the reign of sikandar lodi but a state account were still kept in hindi it wa not compulsory for hindu employee to learn persian',
#  'barabanki district',
#  'i am more accustomed to the various drama that are produced from the studio of american and british moviemakers but scriptwriter neither in hollywood or bollywood could have put together a more enthralling drama than that which occurred over the course of the past four week and finally culminated at the chepauk in chennai',
#  'beleif in one godreligious instructionsheavenhellcouragefaith ar e the issue which have repeatedly instructed',
#  'you d be planning and providing a range of play opportunity for the child together with early year education',
#  'unlike autosomal gene sexlinked gene like those responsible for redgreen colourblindness and haemophilia already mentioned occur singly in the x chromosome without any partner allele in the y chromosome',
#  'if we do so and consider a natural automaton like the living brain of a gorilla we find that it storage capacity is of the order of bit which is to million time greater than that of the largest manmade computer',
#  'also for search and rescue application a well',
#  'and i d just stop it',
#  'in tax revenue for the city',
#  'he will have to defend his title playing under the new rule early next year',
#  'and that it wa such a shame',
#  'this temple is a part of unesco s international heritage',
#  'revaluation started from madoshiy',
#  'al khwarizmi is known a the father of algebra',
#  'and then she showed them an anomaly',
#  'the manna mentioned in the bible is the dried and solidified honeydew secreted by the bug trabutina living on the tamarisk tree',
#  'vedic culture',
#  'one must not just be on time but ahead of time',
#  'ramganga begin from the south of main himalaya near nainitalflows through bijnour district and join river ganges near kannouj',
#  'contrary to what one might expect the frog egg is huge compared to the microscopic human ovum',
#  'during a vacation in cuttgck he came face to face with grim reality of india s countryside when he together with a band of dedicated boy defied all inhibition and undertook a nursing expedition during a cholera epidemic',
#  'e big dictionary c analogical dictionary a publication of indian government',
#  'defra state that the air pollution ha important impact on health and easy index banding is made to use a daily warning process which wa issued for air pollution level to bbc weather service defra ha also issued guideline for the people suffering from respiratory and heart disease',
#  'follow the line all the way from b to e',
#  'they talk to international donor',
#  'a cricket match two team or side opened hey bitch',
#  'we ve spent a great deal of time',
#  'of late he say villager have started using poison lrb spraying it around the den rrb jhala s study indicate that per cent of all recorded wolf mortality were due to this',
#  'and anywhere else we go in the world',
#  'after our foreign minister graciously escorted them to kandahar in exchange for the passenger of ic they have gone on to achieve mighty feat of terrorism',
#  'the place where they stayed came to be known a india house',
#  'which celebrated it th anniversary',
#  'it is said that he studied both the quran and the bhagbad geeta',
#  'the profusion of such didactic depiction compensates richly for the diminution of the aesthetic trend of the earlier phase',
#  'for example at the ending of the letter given',
#  'the rajasthan tourism development corporationrtdcmade one part of lalgadh palace in hotel',
#  'a school dropout from coimbatore how he is able to sustaining',
#  'learn the newracreestaophand mobilephilosophicalessay on psychology and education',
#  'i know are important',
#  'near mumbai universityrajabhai gantaghar is situated',
#  'india continued to recognise the islamic republic of afghanistan and had masood khalili right hand man of assassinated alliance commander ahmed shah masood a it friend there',
#  'the desire to escape from this world began to gain momentum',
#  'stump are kept in the bowling line with some gap in between them the middle stump is kept right at the center of bowling crease popping crease is in front of stump is parallel to the bowling crease and it length is same on either side of the stump return crease is perpendicular to other two crease it line is drawn touching the end of popping crease bowling crease',
#  'you don t need a model',
#  'that is why i think all of you',
#  'you simulate the molecular structure of methane ch',
#  'though it is lesser in dimension it is more ornate with bold and round sculpture in the niche and cameo of puranic scene formed by miniature panel',
#  'jawaharlal nehru in his book discovery of india',
#  'what is worth dying for',
#  'many of the poem are thus reminiscent but they are free of morbidity or selfpity of any kind',
#  'that bee and butterfly and such can come back into our city',
#  'the barrel is long and well rounded',
#  'sur ha also written enigmatic verse in place',
#  'and the biggest of the empire on this planet the british empire',
#  'so look at the beauty from the desert society',
#  'sold his child for pornography',
#  'and if you open the newspaper any day of the week',
#  'so i applied that i said i haven t the foggiest idea',
#  'taking formal action',
#  'the author ha tried to face boldly the psychological dilemma caused by a conflict of loyalty loyalty to married love and loyalty to love free and unfetteredwithout sentimentalising and without moralising',
#  'samuel clemens mark twain',
#  'to diagnose what s going on',
#  'he is perhaps the greatest writer of vachanas in kannada',
#  'along with the fun it is also a time for prayer',
#  'according to islam god ha from time to time ha made some person a his messenger to provide path for the human on earth',
#  'undermine an objective morality',
#  'it wa not a difficult task for bhagat singh and b k dutt to dodge the usual vigil of the police after throwing the bomb in the central hall of the assembly but a decision not to run away had already been taken',
#  'and he said if my wish get fulfilled',
#  'correcting fluid lrb like tippex rrb',
#  'the national average at ton per acre wa far too low in comparison with ton in hawaii and ton in java',
#  'after having composed the book he sent it to kashmir but the people there did not adopt it being in such thing haughtily conservative',
#  'fatehpur sikhri',
#  'the king wa supposed to be very attentive during the trial',
#  'sometime later naren gave up his job and opened a restaurant which became a centre for procurement of arm and exchange of information',
#  'the caterpillar of pieris breed on the leaf of cabbage mustard and other cruciferae sometimes also capparidaceae',
#  'the state should not be in the business',
#  'development of mobile service happened by using the concept of six m earlier m servicedevelopment concept which wa developed by writer tomi ahonen with joe barrett of nokia and paul goding of motorola these six m are place time ownership mass user fund and automation six m five m concept is used widely in telecom facility literature and mostly by big industry service for umts wa the first book written by ahonen and barrett in which discussed this concept',
#  'the manufacture of several new item like heavy calibre gun torpedo boat and degaussing cable wa also started',
#  'it is the honey of this specie that is gathered by forest personnel and sold in our market',
#  'the city were generally planned in the form of a square or a rectangle',
#  'in a way this theory permeates into all other theory of aging',
#  'no extra blood will be taken',
#  'piece by piece the jigsaw ha to be put together by archaeologist art historian linguist ethnologist and musicologist working a team for several year',
#  'come to empathize with you',
#  'a brevity brevity of everything with this child',
#  'sudhodhana held naming baptism celebration no fifth day and intellectual brahmin were invited to study about his future life',
#  'in third century emperor ashok built a pillar in madhyapradesh near saanchi',
#  'i wanted to be alone and think in silence of the wonder and glory of it all',
#  'so religion can confront the house of meat',
#  'this wa in addition to his unique invention of totally cutout monolithic temple form or vimanas the socalled rathas and some open air basrelief composition of considerable size and superb quality all confined to the great pallava portcity of mamallapuram or mahabalipuram',
#  'indeed one might even say that the western interlude and periodic spell of missionary fervour were distraction that served a healthy diversion enriching his spirit and enlarging his mental horizon',
#  'that men are superior woman are inferior',
#  'before that in the year poet muhammad iqbal had suggested two different country',
#  'is this the perfect expression',
#  'and so amitabha decided that he would take that innovation',
#  'is i had to sell my work and not myself',
#  'wa a sense of courage',
#  'it wa one of the premier instrument in the court of akbar and abul fazl name shihab khan of gwalior and purbin khan a the two court beenkars lrb player on the been rrb',
#  'if you use a textphone the number is',
#  'in clash with the british twothirds of the land area of nepal wa to be surrendered to the british india and today form part of himachal pradesh uttarakhand and west bengal',
#  'the vote of their relative is what hundal is banking on and his party is counting on the half million dollar it rich candidate will rake in from the u',
#  'for the further study',
#  'is',
#  'according to act governor can use all his power for making of rule which are used for smooth going of the state work plus he can divided the workload in minister',
#  'harivanshray bachchan',
#  'remember that innocent people lost their life because the cinema s management wa criminally negligent',
#  'but i didn t really fully understand what had happened to me at swarthmore',
#  'this is very important for hindu to get very good education and good habit',
#  'other polluter of anthropogenic emission sulfate aerosol specially generate cooling effect because they reflect the coming sunlight this is one of partial cause of the coldness which wa found in middle of th century',
#  'the round began after the islamic caliphate',
#  'once again the economy is in the doldrums',
#  'eight pillar arch decorate the place of floor',
#  'the capability to separate carbon decrease with the warming of the ocean',
#  'i grew up not far from here in washington dc',
#  'this wa the plea taken by many of the illustrious lawyer during the ina trial at red fort challenging the jurisdiction of the indian court to try these international matter since the provisional government of free india had formally declared war',
#  'we have already noted in fact that on account of it peculiar intellectual trend it regard the apprehension of ultimate reality to be the highest value and give the practical value a lower status',
#  'i ll end with a quotation by mahatma gandhi',
#  'because walking ha a real power',
#  'i always tell my student if you have a deceptive cadence',
#  'very high quality at very very low cost',
#  'now after year the odd chinese in kolk ata who constitute well over per cent of the chinese in india are jittery again',
#  'there ha to be a willingness to do good deed',
#  'vyahalo',
#  'if you ve got talent and energy and skill',
#  'they have to put it into box',
#  'female to reduce the speed of partner can stabd on staircase or stool',
#  'but too often it s not',
#  'the cause of celebrating the diwali is different in every district or areabut on the every palace this festival is going on various generation',
#  'a much depends on mamata',
#  'that men are strong woman are weak',
#  'in the persian and turkish state the king had deviated from the islamic way only in the field of constitutional law and to some extent in the system of land revenue',
#  'the national museum ha been a hostage to the department of culture after the retirement of lp sihare it last professional directorgeneral say rupika chawla noted art restorer',
#  'if you look at the xaxis of this graph',
#  'the dangerous matter like western berlinaustria and lao problem resolution were backed by him',
#  'it ispertinent to mention here that basava wa the son of one such leader',
#  'tipper wa saying one more burger with fry',
#  'we identify different living thing in different way',
#  'to any position they please',
#  'there are district in rajasthan',
#  'now talk of a divided place the country wa cut in two',
#  'into your college',
#  'the normal temperature of a goat is degree c lrb degree f rrb',
#  'whistling laughter',
#  'bread',
#  'i can t forget auntie',
#  'suddenly his companionthe local trackertaps him on his shoulder',
#  'we considered it prudent therefore to recommend a small further increase for october before the minimum wage is reviewed in full again',
#  'there are ton of school project',
#  'or nomadic pastoralists in central asia or a dozen different culture',
#  'it measurement showed that it planning wa made using a square grid of m',
#  'how shall i come out o lord',
#  'that i have written in english seems to be the delusion',
#  'in commemoration of the coulumbia tragedy steve morse composed a song called deep purple which wa called lost contact in this album bananassong is also available',
#  'they start off like camel no way to resolve it',
#  'then you ll love the whole world every creature of the world will become eligible for your love',
#  'cvmri allows the coronary artery to be visualised and even minute blockage detected',
#  'emperor akbar wa the grandson of the founder of the mughal empire jahiruddin mohammad babur and the son of nasiruddin humayun and hamida bano',
#  'for those of u or rather those of you who were born after it is difficult to imagine how it felt to live in a country ruled by a people who did not belong to it',
#  'so let s start with the data',
#  'mumbai is also facing the problem of rapid urbanization like the problem of mass urbanization faced by city of developed country',
#  'again the government remained inactive',
#  'if they are stuck first',
#  'with richness',
#  'in june the congress working committee declared that the only satisfactory alternative to the white paper wa a constitution drawn up by a constituent assembly elected on the basis of adult suffrage',
#  'now he could not tolerate',
#  'the one used at muzafferpore by khudiram bose on april wa traced to the centre',
#  'accident of thing dropping on people s head illness etc',
#  'we re told what shape we re supposed to be in',
#  'the secular character of the state could not likewise be done away with lrb para rrb',
#  'part of what we re finding with this',
#  'this one is in england',
#  'minamata a small picturesque town evinced a disease called by it name minamata disease that devoured score of men and woman and child',
#  'little doubt',
#  'february wa a day of collective mourning for the indian middle class',
#  'the koran declares that it come',
#  'translucent white marble wa brought from rajasthan jasper from punjab jade and crystal from china',
#  'before the umpire declare the batsman out generally any member of the fielding sidemostly the bowler make an appeal this is howsz that',
#  'middle east asian hindi literature',
#  'what ha happened in spain',
#  'secondly mr gandhi is an educated man and a recognised leader and this make the campaign all the more harmful',
#  'da babu wa leading this movement in bengal',
#  'the other thrust of jhala s struggle is to build a national management strategy for wolf',
#  'to share this pioneering diagnostic approach',
#  'vijayanagar empire wa founded in ad with the intention of saving hinduism from the onslaught of islam',
#  'the number of slogas in kurma puran is',
#  'but lightning struck rather slowly in our country in those day',
#  'the girl s hostel in punjab engineering college is on the name of kalpana chawla apart from this for inr twenty five thousand rupee one medal and the best student of aeronautical engineering discipline is given a certificate and a prize',
#  'life history',
#  'in this river recieves the meltwater from nanda devi kamat parbat and trishul peak',
#  'who contacted the coast guard',
#  'it need truth and beauty',
#  'the sky clap it hand in silent glee my joy is full with colour and sound is kalimpong aware of it',
#  'the chief symptom of the disease are rise in temperature which continues for three or four day eye become bright pink in colour eyelid may be swollen and show watery condition a harsh cough and serious nasal discharge',
#  'i did not want to study surgery don t ask me why',
#  'and the more you understand that',
#  'it is being considered that the current effect on natural environment and human life is mainly due to global warming to some extent according to the ipcc report glacier retreat ice shelf disruption like the larsen ice shelf rise in the sea level and extreme weather event are attributed to the global warning',
#  'he ha used his power to expand education health and environment',
#  'even with a talented translator',
#  'microsoft indic language input toolbeta',
#  'to build a map of the environment',
#  'get urine tested for ketone and blood for glucose every four to six hour',
# ...
#  'mommy i know you have been stopped',
#  'cow are poor milkyielders',
#  'we participate',
#  'but the rjd party formed in ha completed year and performed better in financial growth',
#  'in india it sometimes lead to communal violence which diverts attention immediately from labour s demand',
#  'what it show is that we do roughly about percent',
#  'the day of full moon in the month sravana is a fastday hoiy to somanath',
#  'the formal closure of a cycle of thirty two fast on the full moon day is very popular among the woman and is supposed to bring long life and good luck to their husband',
#  'there is no end to human cleverness',
#  'for many reason legal institution lag behind change of public opinion much more than other institution',
#  'i can not say that my head wa not turned',
#  'therein lie the danger',
#  'after partition when almost all the muslim leauge leader had left the muslim in india to their fate and migrated to pakistan muslim leadership passed into the hand of the nationalist muslim who had always advocated a united indian nation',
#  'for instance soni claimed that the management ha agreed to treat the day lost in strike a working day and no deduction will be made in wage',
#  'he wrote it in a little over a year when his health wa far from satisfactory',
#  'and delivered ten of million of service and product',
#  'this look like another very aggressive bee',
#  'a new creation in paradise',
#  'an averagesized hen can conveniently brood to chick',
#  'fallen nation do not rise without a miracle',
#  'for cws ozone ppb year average time hour till the year obtained from maximum map per year based on average of or more year',
#  'eventually the kuomintang split into two faction the right and the left',
#  'one example would be',
#  'cabinet government',
#  'the story of history also play an important role',
#  'on the mountain shore of ganges baboon red monkey brown bear fox panther snow leopard deer barking deer sambhar musk buck sero mountain antelope sahi etc are found in many number',
#  'content of mythology detail of vedic',
#  'those who are of vaishnav sect and majority of hindu believe in incarnation of bhagawan vishnu matshya fish kurma tortoise varaah boar wamana dwarf narsinh lionmanparshurama rama krishna budhha and kalki',
#  'because people used to sew and they needed a pin cushion',
#  'a per the discussion with balmiki ramsita and laxman stared living in chitrakut',
#  'american presidential election',
#  'later in the tenth and eleventh century several shaivite and vishnavite acharyas tried to put the idea of bhakti on a philosophical basis',
#  'hermit sum up the search party came to power ha beach sampati where their gift wa from',
#  'since a limited responsible government wa established only at the provincial level the nationalist naturally asked for more power for provincial legislature',
#  'he wa aware of this conflict and this vacillation and knew also that his own primary duty or dharma wa a a singer a god s minstrel and not his soldier',
#  'under rough weather transhipment to boat from the ship becomes quite difficult and sometimes dangerous also',
#  'that a kid wanted to get published',
#  'her father name wa ratri simha',
#  'it coastal border with arabian sea ia about kilometer',
#  'in top newspaper of country in hindi none from english',
#  'the company made an offer to buy share of it indian subsidiary from shareholder which will eventually lead to it delisting from stock exchange',
#  'he gave open ness to hindi',
#  'is how do you coordinate lot of these robot',
#  'that is solely the job of the regulator',
#  'he learned urdu in kayastha paathshaalas which wa considered a the the first step to get a law graduation',
#  'grassroots to global',
#  'the kashmiri militant group wa always described a dreaded and hardcore',
#  'when i came to this world i had nothing but a reed given to me which wa to find it only value in producing music',
#  'it contains the name of some minor smritis such a atri harita and daksha',
#  'for few month he ha taken care of edition of maryada bulletin for six year he did editing of magazine named madhuri in from banaras started his magazine patra hansa and in the beginning of started one more weekly edition named jaagran',
#  'al gore know it s basically everything',
#  'during the trial all established procedure were given a goby and a totally novel highhanded procedure wa adopted for convicting and passing the sentence in the bhagat singh case',
#  'discussion in the council when acting in it legislative capacity became oral instead of in writing bill were referred to select committee and not to single member legislative business wa conducted in public instead of in secret and report of the proceeding were officially published',
#  'take a lot of patience',
#  'help young child to develop a sensibly cautious attitude by taking care with everyday household product and by using all manufactured chemical correctly and for their intended use',
#  'tajmahal since yearsattracts lakh people where there are more foreign country',
#  'neither the sardar nor the maulana is in a position to give any guarantee in the present state of our slavery',
#  'the idea of the multiplicity of god wa reconciled with the vedic concept of unity with the help of the theory of symbol and incarnation',
#  'in serious case they may decide to recommend a prosecution if the prosecution is successful the court may impose prohibition on process and the use of premise or equipment fine and possibly imprisonment',
#  'the indigenous production needed improvement in quality and a considerable extension to other item for which the country had to depend on import',
#  'and said there s a processor inside',
#  'kabir belief in the name of god than his form',
#  'it is more economic and efficient than the steam engine which it fast displaced',
#  'we do not fully understand the cause of them all but there are step we can take avoid some of them',
#  'a on the contrary the government will emerge from this crucible of fire even stronger',
#  'if the british ruling class are manifestly failing in spite of their prestige and tradition and training what shall we say of our indian prince who for generation past have grown up in decadence and irresponsibility',
#  'blank space',
#  'after that it remains divided between the north indian gupta s and sasani empire of persia',
#  'and nobody to this day',
#  'through this the whole nation realized that he is interested in adopting an accommodative justice',
#  'or if you go in kind of halfheartedly',
#  'series city of uttar pradesh',
#  'that is why congress president welcomed subhash babu with oxen dragging the chariot',
#  'of the world and in all case except one',
#  'index on the subject of puraanas here the meaning and reference have been given for the word that have come in the veda',
#  'i couldn t build this the way i knew',
#  'the text here are about the final judgment described in the quran and the versus from the lesser surah are incorporated in it',
#  'this is a selfintroductory project especially for young people who use drug in wythenshawe',
#  'but our mba program don t teach kid to be entrepreneur',
#  'during pregnancy it is essential to give the sow regular exercise',
#  'because one cup of food a day',
#  'in the rainforest of west africa there can be individual under each square metre',
#  'ash and partly burnt lrb or unburnt rrb body are discharged into the river turning it into a mere drain or cesspool',
#  'this wa followed by transportation of madanlal dhingra of savarkar s group for killing curzon wyllie with a bomb in london',
#  'no no what you talking about',
#  'priest poet list',
#  'there is river rafting in ganges',
#  'they re willing to invest in a relationship',
#  'what s the matter the pearl of wisdom',
#  'the greatful foreigner gladly turn syama s lover but when he come to know of her inhuman conduct by which she procured his freedom he is filled with disgust and shame and leaf her',
#  'if the umpire find the appeal right then he agrees to the bowler and lift his index finger to say out',
#  'this is a straw',
#  'she ha also done caricature',
#  'the economicsand politicsof power can scarcely be done justice to in this space',
#  'and so one of the challenge you have in health care is',
#  'it s more important than ever to find way to maintain',
#  'in the hinterland of the country',
#  'specified number is not set',
#  'measles is a highly infectious disease and it kill and disables child and adult',
#  'we heard a lot about technology this week',
#  'his house is now in the village khatakarkala of navamshahar of indian punjab',
#  'good specimen have two white collar one round the jaw and the other at the brisket',
#  'is there no gleam of intelligence in insect behaviour',
#  'you will probably need to visit the court where the procedure will be explained to you and you may be asked for evidence of the problem',
#  'if you ask child and teenager who use drug why they do it they say',
#  'the child enthusiastically got after me and said',
#  'is this true',
#  'highest century in test cricket',
#  'it wa felt that attention should be paid to the intention of the framer of the constitution a expressed through the preamble',
#  'which is just a good a my link a long a we have a browser',
#  'now it may be that in the process of dynamic movement certain existing relationship are altered varied or affected',
#  'anybody can do it turn out',
#  'harivansh ray bachchan english wikipedia',
#  'so if you have lot of robot carrying the same thing',
#  'raja birble',
#  'and we are much more confident now than we were two year ago',
#  'keep dangling curtain bed spread and drying washing well away form fire and cooker',
#  'bhattal hope to escape loss of vote by calling the case political vendetta by the badal government',
#  'the news will be made known in lahore on the early morning of march',
#  'pranav mistry so there are lot of company',
#  'often with potent symbolism',
#  'the wide range of colour is due to either specific pigment or due to multiple reflection selective absorption refraction defraction and scattering or interference of light wave by the peculiarity in the minute structure of the body integument',
#  'to track blood flow in the brain',
#  'so here the process on board',
#  'a country that so many learned scholar and journalist',
#  'a recent survey indicates that the number of twowheelers in our country is expected to touch the million mark by ad',
#  'these people were thinker doer',
#  'rational selfinterest is not always the dominating factor',
#  'many living specie in this area were declared a protected a they are rare specie',
#  'he said thank you we had a baby i said congratulation',
#  'the fog and rain',
#  'environmental effect',
#  'corporation minister dk shivakumar ha been accused of landgrabbing',
#  'again there were twist and turn the following day which left the indian tribe holding the favour of the goddess and when steve waugh departed early the next morning a seemingly meagre chase of wa left for the home tribe',
#  'the rate of collagen synthesis is high in youth and decline through rest of the life',
#  'where the percentage of illiteracy is very high',
#  'a survey of global company by management consultant at kearney found most foreign investor sanguine about india but reluctant to make investment',
#  'i mean most imaginative use ever',
#  'africa can only be transformed by enlightened leader',
#  'between capability and foresight',
#  'of all the initiative since his now famous cairo speech',
#  'but marathi people call it mumbai or bambai and hindi speaking people call it bambai only',
#  'we read in history not only ancient but even fairly recent history of the rich of india',
#  'how much variation is there within a school or between school',
#  'on the national and international level salman rashdi and arvind adig were honoured',
#  'in the rajya sabha such discussion can generally be held from pm to pm on any day allotted for the purpose by the chairman',
#  'in a meeting in london while speaking in english he mesmerised all the spectator present in the meeting',
#  'on one occasion basava became selfconscious that he wa the donor and all others were donee',
#  'the excise duty of per cent on medium cloth wa also withdrawn so that it offtake might improve',
#  'very little discussion because we were exhausted',
#  'population of nepal follow hindu religion',
#  'were ungovernable',
#  'for muslim all religious book given by god to the rasuls are legitimate',
#  'the vanar army which wa searching to sita they visited hermite in cave',
#  'outside link',
#  'in may thirtyseven person including barindra ghose his brother aurobindo ullaskar dutt hem chandra da upendra nath banerjee and others were arrested by the british and put on trial',
#  'on lalkila king of france nadir shah attacked and took swarna mayur throne along with him which later became an emblem of iran i emperor',
#  'kabeerpanthi a group pf religious people believe that the principle of kabeer are the basis for their life',
#  'fishing trade organisation like the kochibased marine product export development authority lrb mpeda rrb and government of coastal state like kerala and orissa argued that the elasmobranch accounted for a much a per cent of india s total marine catch and that a blanket ban would affect the livelihood of the fishing community',
#  'lakhimpur kheri district',
#  'of kid being so much better than adult',
#  'china had an infrastructure disadvantage',
#  'this wa a reference to the perennial shortage of cigarette in the socialist dreamland',
#  'thus along with the governorgeneral and the commanderinchief the council a constituted under the act of consisted of member',
#  'but that when you ve lived on charity and dependent your whole life long',
#  'one is not subordinate to the other in it own field',
#  'which wa founded by tedsters including',
#  'pandit jawaharlal nehru wa the first primeminister of india',
#  'if we measure the three crossover ratio between a and b b and c and a and c we may find that the crossover value between a and c equal either the sum of the crossover value between ab and bc or the difference between them',
#  'bra born stadium is one of the oldest stadium in india',
#  'what troubled me wa that this topdown approach is still around',
#  'this low ph mean high acidity and subsequently high corrosivity',
#  'the council of minister may in a sense be described a the grand executive committee of the parliament charged with the responsibility of governance on behalf of the parent body',
#  'not surprisingly then on october it wa general pervez musharraf and not general ziauddin to whom the pakistan army pledged allegiance in the countercoup against prime minister nawaz sharif',
#  'which is a metaphor for a place of perspective',
#  'the liaison officer s name wa cleared hour before the team landed at bagram airbase near kabul',
#  'it wa india s way in the past to welcome and absorb other culture',
#  'this is the bedrock of the study of nature a key science on which many others depend',
#  'the mahatma could rise above the limitation of his own bias but would his follower do so',
#  'even though all these state use to fight with each other but because of belonging to same muslim culturecontact wa maintained between people',
#  'the reaction product',
#  'wk yeah if they can help me with material yeah',
#  'is if you build a toilet and you leave it there',
#  'most people have cooking fire in the world',
#  'you ve got to cross all these border',
#  'and other thing that i don t aren t familiar with',
#  'it varies',
#  'the reason obviously wa that the flood of new member many of whom did not wholly agree with the fundamental principle of the congress but were attracted by the glamour of power submerged the older element and appreciably changed the general colour of the party giving it a conservative and communal tinge',
#  'and what a perfect place to do that ted',
#  'at the end of mating the male usually get exhausted and die within a few hour',
#  'some regular uncover will also help you for this',
#  ...]

# %%
df['english_sentenced_text'] = english_sentenced_text

# %%
exclude = set(string.punctuation)
remove_digits = str.maketrans("", "", digits)

# %%
df['hindi_sentence']=df['hindi_sentence'].apply(lambda x: re.sub("'", '', x))
df['hindi_sentence']=df['hindi_sentence'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
df['hindi_sentence']=df['hindi_sentence'].apply(lambda x: x.translate(remove_digits))
df['hindi_sentence'] = df['hindi_sentence'].apply(lambda x: re.sub("[२३०८१५७९४६]", "", x))
df['hindi_sentence']=df['hindi_sentence'].apply(lambda x: x.strip())
df['hindi_sentence']=df['hindi_sentence'].apply(lambda x: re.sub(" +", " ", x))
df['hindi_sentence'] = df['hindi_sentence'].apply(lambda x : 'START_ '+ x + ' _END')

# %%
df['hindi_sentence'][0]
# Out:
# 'START_ राजनीतिज्ञों के पास जो कार्य करना चाहिए वह करने कि अनुमति नहीं है _END'

# %%
english_words = set()
for eng in df['english_sentenced_text']:
  for word in eng.split():
    if word not in english_words:
      english_words.add(word)

hindi_words = set()
for hindi in df['hindi_sentence']:
  for word in hindi.split():
    if word not in hindi_words:
      hindi_words.add(word)

# %%
print(english_words.__len__())
print(hindi_words.__len__())
# Out:
# 27128
# 36975

# %%
df['len_english_words'] = df['english_sentenced_text'].apply(lambda x: len(x.split()))
df['len_hindi_words'] = df['hindi_sentence'].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#            source  ... len_hindi_words
# 25520   indic2012  ...              21
# 118633        ted  ...               9
# 113495      tides  ...               9
# 29783       tides  ...               6
# 111804      tides  ...              24
#
# [5 rows x 6 columns]

# %%
# Taking only text which are less than or equal to 20
df = df[df['len_english_words']<=20]
df = df[df['len_hindi_words']<=20]

# %%
df.shape
# Out:
# (16514, 6)

# %%
input_words = sorted(list(english_words))
target_words = sorted(list(hindi_words))
num_encoder_tokens = len(english_words)+1
num_decoder_tokens = len(hindi_words)+1
num_encoder_tokens, num_decoder_tokens
# Out:
# (27129, 36976)

# %%
print(input_words.__len__())
print(target_words.__len__())
# Out:
# 27128
# 36975

# %%
input_token_index = dict([ (word, i+1) for i, word in enumerate(input_words)])
target_token_index = dict([(word, i+1) for i, word in enumerate(target_words)])

# %%
input_token_index
# Out:
# {'a': 1,
#  'aa': 2,
#  'aabb': 3,
#  'aac': 4,
#  'aacharan': 5,
#  'aadam': 6,
#  'aadi': 7,
#  'aadikavya': 8,
#  'aadimindoeuropean': 9,
#  'aadiparva': 10,
#  'aae': 11,
#  'aaen': 12,
#  'aag': 13,
#  'aagra': 14,
#  'aah': 15,
#  'aai': 16,
#  'aainaeakbary': 17,
#  'aaj': 18,
#  'aakashdeep': 19,
#  'aakhr': 20,
#  'aakhus': 21,
#  'aakrnsa': 22,
#  'aakul': 23,
#  'aamer': 24,
#  'aankhen': 25,
#  'aanre': 26,
#  'aap': 27,
#  'aapsall': 28,
#  'aapsallits': 29,
#  'aarac': 30,
#  'aarthie': 31,
#  'aarti': 32,
#  'aarun': 33,
#  'aasan': 34,
#  'aashram': 35,
#  'aathri': 36,
#  'aatre': 37,
#  'aatri': 38,
#  'aauu': 39,
#  'aayats': 40,
#  'aaygarh': 41,
#  'aayouva': 42,
#  'aaytmuhakamaat': 43,
#  'aaytmutshahibat': 44,
#  'ab': 45,
#  'abad': 46,
#  'abandon': 47,
#  'abandoned': 48,
#  'abandoning': 49,
#  'abani': 50,
#  'abbas': 51,
#  'abbasi': 52,
#  'abbasioan': 53,
#  'abbasis': 54,
#  'abbaskingdom': 55,
#  'abbot': 56,
#  'abbottabad': 57,
#  'abbreviated': 58,
#  'abbreviation': 59,
#  'abbullah': 60,
#  'abc': 61,
#  'abcl': 62,
#  'abdel': 63,
#  'abdicate': 64,
#  'abdicted': 65,
#  'abdomen': 66,
#  'abdominal': 67,
#  'abduct': 68,
#  'abducted': 69,
#  'abduction': 70,
#  'abductor': 71,
#  'abdul': 72,
#  'abdullah': 73,
#  'aberdeen': 74,
#  'aberrant': 75,
#  'aberration': 76,
#  'abetment': 77,
#  'abetted': 78,
#  'abetting': 79,
#  'abhimaan': 80,
#  'abhimanyu': 81,
#  'abhimanyuplucky': 82,
#  'abhinav': 83,
#  'abhinay': 84,
#  'abhisekh': 85,
#  'abhishek': 86,
#  'abhisheka': 87,
#  'abhishekh': 88,
#  'abhu': 89,
#  'abhyaaran': 90,
#  'abhyankar': 91,
#  'abhyaranya': 92,
#  'abi': 93,
#  'abid': 94,
#  'abide': 95,
#  'abided': 96,
#  'abiding': 97,
#  'abidjan': 98,
#  'ability': 99,
#  'abilityfrom': 100,
#  'abinav': 101,
#  'abinetoan': 102,
#  'abishek': 103,
#  'abitabh': 104,
#  'able': 105,
#  'ablebodied': 106,
#  'abnormal': 107,
#  'aboard': 108,
#  'abode': 109,
#  'abolish': 110,
#  'abolished': 111,
#  'abolishes': 112,
#  'abolishing': 113,
#  'abolition': 114,
#  'abondoned': 115,
#  'aboriginal': 116,
#  'aborted': 117,
#  'abortion': 118,
#  'about': 119,
#  'above': 120,
#  'abovementioned': 121,
#  'abraham': 122,
#  'abrahamic': 123,
#  'abridged': 124,
#  'abroad': 125,
#  'abru': 126,
#  'abscence': 127,
#  'abscess': 128,
#  'abscond': 129,
#  'absconded': 130,
#  'absconding': 131,
#  'absence': 132,
#  'absent': 133,
#  'absentia': 134,
#  'absian': 135,
#  'absolute': 136,
#  'absolutely': 137,
#  'absolve': 138,
#  'absolved': 139,
#  'absorb': 140,
#  'absorbed': 141,
#  'absorbent': 142,
#  'absorbing': 143,
#  'absorbs': 144,
#  'absorption': 145,
#  'abstain': 146,
#  'abstaining': 147,
#  'abstract': 148,
#  'abstruse': 149,
#  'absurd': 150,
#  'absurdity': 151,
#  'abu': 152,
#  'abul': 153,
#  'abundance': 154,
#  'abundant': 155,
#  'abundence': 156,
#  'abuse': 157,
#  'abused': 158,
#  'abusive': 159,
#  'abutting': 160,
#  'abyss': 161,
#  'ac': 162,
#  'academic': 163,
#  'academically': 164,
#  'academy': 165,
#  'acc': 166,
#  'acccording': 167,
#  'acceded': 168,
#  'accelerate': 169,
#  'accelerated': 170,
#  'accelerating': 171,
#  'acceleration': 172,
#  'accent': 173,
#  'accentuated': 174,
#  'accentuating': 175,
#  'accept': 176,
#  'acceptable': 177,
#  'acceptance': 178,
#  'accepted': 179,
#  'accepting': 180,
#  'accepts': 181,
#  'access': 182,
#  'accessed': 183,
#  'accessibility': 184,
#  'accessible': 185,
#  'accession': 186,
#  'accessory': 187,
#  'accident': 188,
#  'accidental': 189,
#  'accidentally': 190,
#  'acclaim': 191,
#  'acclaimed': 192,
#  'accommodate': 193,
#  'accommodated': 194,
#  'accommodation': 195,
#  'accommodative': 196,
#  'accomodation': 197,
#  'accompanied': 198,
#  'accompaniment': 199,
#  'accompanying': 200,
#  'accomplice': 201,
#  'accomplished': 202,
#  'accord': 203,
#  'accordance': 204,
#  'accorded': 205,
#  'according': 206,
#  'accordingly': 207,
#  'accoriding': 208,
#  'account': 209,
#  'accountability': 210,
#  'accountable': 211,
#  'accountancy': 212,
#  'accountant': 213,
#  'accounted': 214,
#  'accounting': 215,
#  'accountingbr': 216,
#  'accpet': 217,
#  'accpeted': 218,
#  'accredited': 219,
#  'accretion': 220,
#  'accumulate': 221,
#  'accumulated': 222,
#  'accumulating': 223,
#  'accumulation': 224,
#  'accuracy': 225,
#  'accurate': 226,
#  'accurately': 227,
#  'accusation': 228,
#  'accused': 229,
#  'accuses': 230,
#  'accusing': 231,
#  'accustomed': 232,
#  'acday': 233,
#  'ace': 234,
#  'aceitha': 235,
#  'achalayatan': 236,
#  'achar': 237,
#  'achary': 238,
#  'acharya': 239,
#  'acharyaramchandra': 240,
#  'acharyas': 241,
#  'achieve': 242,
#  'achieved': 243,
#  'achievement': 244,
#  'achieves': 245,
#  'achieving': 246,
#  'achyuta': 247,
#  'acid': 248,
#  'acidic': 249,
#  'acidification': 250,
#  'acidified': 251,
#  'acidity': 252,
#  'acknowledge': 253,
#  'acknowledged': 254,
#  'acknowledgement': 255,
#  'acknowledges': 256,
#  'acknowledging': 257,
#  'acme': 258,
#  'acn': 259,
#  'acolyte': 260,
#  'acoording': 261,
#  'acorn': 262,
#  'acquaint': 263,
#  'acquainted': 264,
#  'acqueous': 265,
#  'acquiescence': 266,
#  'acquire': 267,
#  'acquired': 268,
#  'acquires': 269,
#  'acquiring': 270,
#  'acquisition': 271,
#  'acquitted': 272,
#  'acre': 273,
#  'acreage': 274,
#  'acrobat': 275,
#  'across': 276,
#  'acsbieen': 277,
#  'act': 278,
#  'acted': 279,
#  'acting': 280,
#  'action': 281,
#  'activate': 282,
#  'activated': 283,
#  'activation': 284,
#  'activator': 285,
#  'active': 286,
#  'actively': 287,
#  'activeprone': 288,
#  'activewith': 289,
#  'activist': 290,
#  'activitie': 291,
#  'activitiesthere': 292,
#  'activity': 293,
#  'actor': 294,
#  'actress': 295,
#  'actual': 296,
#  'actually': 297,
#  'actuator': 298,
#  'actvities': 299,
#  'acumen': 300,
#  'acutan': 301,
#  'acute': 302,
#  'acutely': 303,
#  'ad': 304,
#  'ada': 305,
#  'adaaccepted': 306,
#  'adalats': 307,
#  'adam': 308,
#  'adamant': 309,
#  'adamont': 310,
#  'adan': 311,
#  'adapt': 312,
#  'adaptability': 313,
#  'adaptation': 314,
#  'adapted': 315,
#  'adapting': 316,
#  'adar': 317,
#  'adarah': 318,
#  'adarvavedait': 319,
#  'adawlut': 320,
#  'adawluts': 321,
#  'aday': 322,
#  'add': 323,
#  'adda': 324,
#  'added': 325,
#  'addicted': 326,
#  'addiction': 327,
#  'adding': 328,
#  'addition': 329,
#  'additional': 330,
#  'additionally': 331,
#  'addon': 332,
#  'address': 333,
#  'addressed': 334,
#  'addressing': 335,
#  'adduce': 336,
#  'aden': 337,
#  'adept': 338,
#  'adequate': 339,
#  'adequately': 340,
#  'adharm': 341,
#  'adhd': 342,
#  'adheek': 343,
#  'adhere': 344,
#  'adhered': 345,
#  'adherent': 346,
#  'adheres': 347,
#  'adhering': 348,
#  'adhikansh': 349,
#  'adhinkash': 350,
#  'adhiraj': 351,
#  'adhirath': 352,
#  'adhishthana': 353,
#  'adhishthanas': 354,
#  'adhivrishan': 355,
#  'adhiyatma': 356,
#  'adhoc': 357,
#  'adhunik': 358,
#  'adhyatmk': 359,
#  'adhyaya': 360,
#  'adhyayan': 361,
#  'adhyayi': 362,
#  'adi': 363,
#  'adig': 364,
#  'adigaimans': 365,
#  'adiguru': 366,
#  'adil': 367,
#  'adipose': 368,
#  'aditala': 369,
#  'aditya': 370,
#  'adjacent': 371,
#  'adjective': 372,
#  'adjoining': 373,
#  'adjourn': 374,
#  'adjourned': 375,
#  'adjournment': 376,
#  'adjudication': 377,
#  'adjunct': 378,
#  'adjust': 379,
#  'adjusting': 380,
#  'adjustment': 381,
#  'adman': 382,
#  'administered': 383,
#  'administering': 384,
#  'administration': 385,
#  'administrative': 386,
#  'administrator': 387,
#  'adminstrator': 388,
#  'admirable': 389,
#  'admiration': 390,
#  'admire': 391,
#  'admired': 392,
#  'admirer': 393,
#  'admissible': 394,
#  'admission': 395,
#  'admit': 396,
#  'admits': 397,
#  'admittance': 398,
#  'admitted': 399,
#  'admittedly': 400,
#  'admitting': 401,
#  'admixture': 402,
#  'adobe': 403,
#  'adolf': 404,
#  'adon': 405,
#  'adopt': 406,
#  'adopted': 407,
#  'adopting': 408,
#  'adoption': 409,
#  'adoptive': 410,
#  'adopts': 411,
#  'adorable': 412,
#  'adoration': 413,
#  'adorn': 414,
#  'adornment': 415,
#  'adquittal': 416,
#  'adressed': 417,
#  'adudaldaula': 418,
#  'adult': 419,
#  'adulthood': 420,
#  'advaita': 421,
#  'advance': 422,
#  'advanced': 423,
#  'advancement': 424,
#  'advancing': 425,
#  'advani': 426,
#  'advaniji': 427,
#  'advantage': 428,
#  'advantageous': 429,
#  'advarugana': 430,
#  'advent': 431,
#  'adventure': 432,
#  'adventurist': 433,
#  'adventurous': 434,
#  'adversary': 435,
#  'adverse': 436,
#  'adversely': 437,
#  'advertised': 438,
#  'advertisement': 439,
#  'advertiser': 440,
#  'advertising': 441,
#  'advice': 442,
#  'advisability': 443,
#  'advise': 444,
#  'advised': 445,
#  'adviser': 446,
#  'adviserasit': 447,
#  'advises': 448,
#  'advising': 449,
#  'advisor': 450,
#  'advisory': 451,
#  'advocate': 452,
#  'advocated': 453,
#  'advocating': 454,
#  'adya': 455,
#  'adyars': 456,
#  'ae': 457,
#  'aeiashmapaan': 458,
#  'aeiou': 459,
#  'aeiseshiq': 460,
#  'aekan': 461,
#  'aerial': 462,
#  'aerodrome': 463,
#  'aerodynamic': 464,
#  'aeronautical': 465,
#  'aeroplane': 466,
#  'aerosol': 467,
#  'aerospace': 468,
#  'aerospaceoptical': 469,
#  'aesire': 470,
#  'aesthetic': 471,
#  'aestivation': 472,
#  'af': 473,
#  'afandi': 474,
#  'afer': 475,
#  'afew': 476,
#  'affair': 477,
#  'affairand': 478,
#  'affan': 479,
#  'affect': 480,
#  'affectation': 481,
#  'affected': 482,
#  'affecting': 483,
#  'affection': 484,
#  'affectionate': 485,
#  'affectionately': 486,
#  'affidavit': 487,
#  'affiliate': 488,
#  'affiliated': 489,
#  'affiliation': 490,
#  'affinity': 491,
#  'affirmation': 492,
#  'affirmative': 493,
#  'afflicted': 494,
#  'affliction': 495,
#  'afflicts': 496,
#  'affluent': 497,
#  'afford': 498,
#  'affordable': 499,
#  'afforded': 500,
#  'affording': 501,
#  'afforestation': 502,
#  'affront': 503,
#  'afghan': 504,
#  'afghanistan': 505,
#  'afghanistanpakistan': 506,
#  'afoot': 507,
#  'afraid': 508,
#  'afresh': 509,
#  'africa': 510,
#  'african': 511,
#  'africo': 512,
#  'afroamerican': 513,
#  'afroasian': 514,
#  'aft': 515,
#  'after': 516,
#  'afterburner': 517,
#  'afterlife': 518,
#  'aftermath': 519,
#  'aftermaximum': 520,
#  'afternoon': 521,
#  'aftersales': 522,
#  'afterthe': 523,
#  'afterward': 524,
#  'afterwards': 525,
#  'afzal': 526,
#  'ag': 527,
#  'aga': 528,
#  'agaidigdh': 529,
#  'again': 530,
#  'against': 531,
#  'againt': 532,
#  'agam': 533,
#  'agama': 534,
#  'agandhavoancontinue': 535,
#  'agara': 536,
#  'agarwal': 537,
#  'agastya': 538,
#  'agastymata': 539,
#  'agd': 540,
#  'age': 541,
#  'aged': 542,
#  'ageearat': 543,
#  'ageing': 544,
#  'agels': 545,
#  'agency': 546,
#  'agenda': 547,
#  'agent': 548,
#  'agentsmoneylenders': 549,
#  'ageold': 550,
#  'aggarwal': 551,
#  'aggravated': 552,
#  'aggravating': 553,
#  'aggred': 554,
#  'aggregate': 555,
#  'aggregater': 556,
#  'aggregator': 557,
#  'aggression': 558,
#  'aggressive': 559,
#  'aggressor': 560,
#  'aggrieved': 561,
#  'aghast': 562,
#  'agile': 563,
#  'agility': 564,
#  'aging': 565,
#  'aginst': 566,
#  'agitate': 567,
#  'agitated': 568,
#  'agitating': 569,
#  'agitation': 570,
#  'agitationists': 571,
#  'agni': 572,
#  'ago': 573,
#  'agochar': 574,
#  'agoleg': 575,
#  'agomusharraf': 576,
#  'agonised': 577,
#  'agonising': 578,
#  'agony': 579,
#  'agp': 580,
#  'agra': 581,
#  'agraaligarhayodhyabarelimerathvaranasibanarasgorakhpurgajiyabadmuradabadsaharanpurfaizabadkanpur': 582,
#  'agraban': 583,
#  'agramandapa': 584,
#  'agrarian': 585,
#  'agravan': 586,
#  'agrawal': 587,
#  'agree': 588,
#  'agreeable': 589,
#  'agreed': 590,
#  'agreegators': 591,
#  'agreeing': 592,
#  'agreement': 593,
#  'agrees': 594,
#  'agricul': 595,
#  'agricultural': 596,
#  'agriculturalist': 597,
#  'agriculture': 598,
#  'agriculturist': 599,
#  'agrigates': 600,
#  'agrobased': 601,
#  'aground': 602,
#  'ah': 603,
#  'ahalya': 604,
#  'ahamadi': 605,
#  'ahamed': 606,
#  'ahars': 607,
#  'ahbibuar': 608,
#  'ahead': 609,
#  'ahi': 610,
#  'ahirs': 611,
#  'ahmad': 612,
#  'ahmadi': 613,
#  'ahmed': 614,
#  'ahmedabad': 615,
#  'ahmedabadbased': 616,
#  'ahmedia': 617,
#  'ahmediyas': 618,
#  'ahmednagar': 619,
#  'ahonen': 620,
#  'ahoss': 621,
#  'ahyaagatoan': 622,
#  'ai': 623,
#  'aiadmk': 624,
#  'aicc': 625,
#  'aid': 626,
#  'aida': 627,
#  'aide': 628,
#  'aided': 629,
#  'aiding': 630,
#  'aif': 631,
#  'aihole': 632,
#  'aiims': 633,
#  'ailing': 634,
#  'ailment': 635,
#  'ailurpara': 636,
#  'aim': 637,
#  'aimed': 638,
#  'aiming': 639,
#  'aimless': 640,
#  'aimplb': 641,
#  'ain': 642,
#  'aincrements': 643,
#  'air': 644,
#  'airbase': 645,
#  'airborne': 646,
#  'airbus': 647,
#  'airconditioned': 648,
#  'aircraft': 649,
#  'aircurrents': 650,
#  'aire': 651,
#  'airindia': 652,
#  'airlifted': 653,
#  'airline': 654,
#  'airpix': 655,
#  'airplane': 656,
#  'airpollution': 657,
#  'airport': 658,
#  'airportbefore': 659,
#  'airspace': 660,
#  'airtelvodafonemtnlbplreliance': 661,
#  'airy': 662,
#  'aisharji': 663,
#  'aishwarya': 664,
#  'aisle': 665,
#  'aisphoert': 666,
#  'ait': 667,
#  'aivdh': 668,
#  'aiyar': 669,
#  'aj': 670,
#  'ajanta': 671,
#  'ajatashatru': 672,
#  'ajay': 673,
#  'ajit': 674,
#  'ajj': 675,
#  'ajmer': 676,
#  'ajonikodith': 677,
#  'ajoy': 678,
#  'ak': 679,
#  'aka': 680,
#  'akabar': 681,
#  'akabari': 682,
#  'akaki': 683,
#  'akansa': 684,
#  'akatatrutv': 685,
#  'akbal': 686,
#  'akbar': 687,
#  'akbarabad': 688,
#  'akbareaazam': 689,
#  'akbareazam': 690,
#  'akbars': 691,
#  'akbbarmausoleum': 692,
#  'akber': 693,
#  'akhabararrat': 694,
#  'akhathan': 695,
#  'akhbar': 696,
#  'akhil': 697,
#  'akin': 698,
#  'akora': 699,
#  'akra': 700,
#  'akregator': 701,
#  'akregatorthis': 702,
#  'akshari': 703,
#  'akshay': 704,
#  'akt': 705,
#  'aku': 706,
#  'akul': 707,
#  'al': 708,
#  'ala': 709,
#  'alabhanainwat': 710,
#  'alacrity': 711,
#  'alahabad': 712,
#  'alai': 713,
#  'alaihi': 714,
#  'alain': 715,
#  'alak': 716,
#  'alakananda': 717,
#  'alakhnanda': 718,
#  'alaknanda': 719,
#  'alam': 720,
#  'alamgir': 721,
#  'alamieyeseigha': 722,
#  'alampur': 723,
#  'alams': 724,
#  'alankaras': 725,
#  'alarm': 726,
#  'alarmed': 727,
#  'alarming': 728,
#  'alayhi': 729,
#  'albania': 730,
#  'albatina': 731,
#  'albedo': 732,
#  'albert': 733,
#  'alberta': 734,
#  'alberto': 735,
#  'albiruni': 736,
#  'album': 737,
#  'alcohol': 738,
#  'alde': 739,
#  'aleather': 740,
#  'alefiya': 741,
#  'alehi': 742,
#  'aleochara': 743,
#  'alert': 744,
#  'alertness': 745,
#  'alex': 746,
#  'alexander': 747,
#  'algae': 748,
#  'algaean': 749,
#  'algal': 750,
#  'algebra': 751,
#  'algorithm': 752,
#  'algorithmic': 753,
#  'alhikma': 754,
#  'ali': 755,
#  'alia': 756,
#  'alias': 757,
#  'alien': 758,
#  'alienated': 759,
#  'alienates': 760,
#  'alienating': 761,
#  'alienation': 762,
#  'aligarh': 763,
#  'alight': 764,
#  'alights': 765,
#  'aligned': 766,
#  'alignment': 767,
#  'aligns': 768,
#  'alike': 769,
#  'alingya': 770,
#  'alipore': 771,
#  'aliraj': 772,
#  'alirajhi': 773,
#  'alireg': 774,
#  'alison': 775,
#  'alities': 776,
#  'alive': 777,
#  'alkali': 778,
#  'alkananda': 779,
#  'alkharismi': 780,
#  'alkhwarizmi': 781,
#  'alkindi': 782,
#  'alkshama': 783,
#  'all': 784,
#  'allaehi': 785,
#  'allah': 786,
#  'allahabad': 787,
#  'allahbad': 788,
#  'allahhuakbar': 789,
#  'allahmaa': 790,
#  'allaihi': 791,
#  'allama': 792,
#  'allan': 793,
#  'allayya': 794,
#  'allegation': 795,
#  'allege': 796,
#  'alleged': 797,
#  'allegedly': 798,
#  'allegiance': 799,
#  'alleging': 800,
#  'allegory': 801,
#  'allehi': 802,
#  'allele': 803,
#  'allembracing': 804,
#  'allen': 805,
#  'allergic': 806,
#  'allergy': 807,
#  'alleviate': 808,
#  'alleviated': 809,
#  'alley': 810,
#  'alliance': 811,
#  'alliancegovernment': 812,
#  'allied': 813,
#  'allindia': 814,
#  'allindian': 815,
#  'allington': 816,
#  'alll': 817,
#  'allmighty': 818,
#  'allocate': 819,
#  'allocated': 820,
#  'allocation': 821,
#  'alloted': 822,
#  'allotment': 823,
#  'allotted': 824,
#  'allover': 825,
#  'allow': 826,
#  'allowance': 827,
#  'allowed': 828,
#  'allowing': 829,
#  'allows': 830,
#  'alloy': 831,
#  'allpowerfulness': 832,
#  'allreligious': 833,
#  'allround': 834,
#  'allrounder': 835,
#  'allroundsocial': 836,
#  'allstone': 837,
#  'allthe': 838,
#  'alltime': 839,
#  'alluded': 840,
#  'alluring': 841,
#  'ally': 842,
#  'almighty': 843,
#  'almoda': 844,
#  'almost': 845,
#  'alms': 846,
#  'almsgiving': 847,
#  'almuqaffa': 848,
#  'alok': 849,
#  'alone': 850,
#  'along': 851,
#  'alongside': 852,
#  'alongwith': 853,
#  'aloof': 854,
#  'aloud': 855,
#  'alpa': 856,
#  'alpha': 857,
#  'alphabet': 858,
#  'alphabetical': 859,
#  'alpine': 860,
#  'alqaeda': 861,
#  'alquran': 862,
#  'already': 863,
#  'alsi': 864,
#  'also': 865,
#  'alsowith': 866,
#  'alt': 867,
#  'altai': 868,
#  'altar': 869,
#  'alter': 870,
#  'alteration': 871,
#  'altered': 872,
#  'altering': 873,
#  'alternate': 874,
#  'alternating': 875,
#  'alternation': 876,
#  'alternative': 877,
#  'alternatively': 878,
#  'alters': 879,
#  'although': 880,
#  'altitude': 881,
#  'alto': 882,
#  'altogether': 883,
#  'altruism': 884,
#  'aluminium': 885,
#  'alvarado': 886,
#  'alvarsthe': 887,
#  'alvida': 888,
#  'alwar': 889,
#  'alwarbharatpurdhaulpur': 890,
#  'alwars': 891,
#  'always': 892,
#  'alzheimer': 893,
#  'am': 894,
#  'amalakas': 895,
#  'amalgamate': 896,
#  'aman': 897,
#  'amanat': 898,
#  'amantha': 899,
#  'amar': 900,
#  'amara': 901,
#  'amarakbaranthony': 902,
#  'amarica': 903,
#  'amarinder': 904,
#  'amarkantak': 905,
#  'amarnath': 906,
#  'amarsinh': 907,
#  'amassed': 908,
#  'amateur': 909,
#  'amaze': 910,
#  'amazed': 911,
#  'amazement': 912,
#  'amazing': 913,
#  'amazon': 914,
#  'amba': 915,
#  'ambalika': 916,
#  'ambashrikhandiwho': 917,
#  'ambassador': 918,
#  'ambedkar': 919,
#  'amber': 920,
#  'ambient': 921,
#  'ambigara': 922,
#  'ambiguity': 923,
#  'ambika': 924,
#  'ambition': 925,
#  'ambitious': 926,
#  'ambrisha': 927,
#  'ambulance': 928,
#  'ambulatory': 929,
#  'ambur': 930,
#  'ameens': 931,
#  'amelioration': 932,
#  'amen': 933,
#  'amend': 934,
#  'amended': 935,
#  'amending': 936,
#  'amendment': 937,
#  'amendmentssubstitute': 938,
#  'amends': 939,
#  'amenity': 940,
#  'amer': 941,
#  'america': 942,
#  'americabecause': 943,
#  'american': 944,
#  'americathis': 945,
#  'ami': 946,
#  'amicably': 947,
#  'amid': 948,
#  'amiina': 949,
#  'amin': 950,
#  'amino': 951,
#  'amir': 952,
#  'amit': 953,
#  'amitab': 954,
#  'amitabachan': 955,
#  'amitabh': 956,
#  'amitabha': 957,
#  'amithab': 958,
#  'amithabh': 959,
#  'amity': 960,
#  'amjad': 961,
#  'aml': 962,
#  'ammai': 963,
#  'amman': 964,
#  'ammonia': 965,
#  'ammonium': 966,
#  'ammunition': 967,
#  'amn': 968,
#  'amnesty': 969,
#  'among': 970,
#  'amongst': 971,
#  'amongthe': 972,
#  'amother': 973,
#  'amount': 974,
#  'amountaccording': 975,
#  'amounted': 976,
#  'amounting': 977,
#  'amp': 978,
#  'ampere': 979,
#  'amphitheater': 980,
#  'amphour': 981,
#  'ample': 982,
#  'amplification': 983,
#  'amply': 984,
#  'amravati': 985,
#  'amrita': 986,
#  'amritrai': 987,
#  'amritsar': 988,
#  'amrutdhara': 989,
#  'amrutha': 990,
#  'amuck': 991,
#  'amused': 992,
#  'amusementswhich': 993,
#  'amusing': 994,
#  'amy': 995,
#  'an': 996,
#  'anaarkali': 997,
#  'anabolic': 998,
#  'anacreon': 999,
#  'anaemia': 1000,
#  ...}

# %%
target_token_index
# Out:
# {'A': 1,
#  'AACप्ले': 2,
#  'ABaavaaoM': 3,
#  'ALDE': 4,
#  'AMDmaana': 5,
#  'AMtriBaia': 6,
#  'ANC': 7,
#  'ANCने': 8,
#  'APaIla': 9,
#  'AQI': 10,
#  'AQyaxaaa': 11,
#  'ASCII': 12,
#  'ASCIIISCII': 13,
#  'ATT': 14,
#  'AVCस्तेरेओ': 15,
#  'AVI': 16,
#  'AXIS': 17,
#  'Aa': 18,
#  'AaD': 19,
#  'AaEama': 20,
#  'AaOVaoigak': 21,
#  'AaOr': 22,
#  'AaQaar': 23,
#  'AaQyaaimak': 24,
#  'Aakr': 25,
#  'Aankhen': 26,
#  'Aaor': 27,
#  'Aap': 28,
#  'Aapkao': 29,
#  'Aapko': 30,
#  'Aapsa': 31,
#  'Aaraop': 32,
#  'AavaXa': 33,
#  'Aavaana': 34,
#  'Aavaasa': 35,
#  'Aayaao': 36,
#  'Abbasके': 37,
#  'Act': 38,
#  'Adalat': 39,
#  'Adobe': 40,
#  'Advanced': 41,
#  'Affairs': 42,
#  'AfsaraoM': 43,
#  'Agency': 44,
#  'Agochar': 45,
#  'Ahmad': 46,
#  'AiBanaoI': 47,
#  'AiBanaoaa': 48,
#  'AiBava': 49,
#  'AiBavaadna': 50,
#  'AiQakar': 51,
#  'AiQaktma': 52,
#  'Ainala': 53,
#  'Air': 54,
#  'AirPix': 55,
#  'AjaI': 56,
#  'Aks': 57,
#  'Alberto': 58,
#  'Alex': 59,
#  'Alignment': 60,
#  'Allenके': 61,
#  'Alvida': 62,
#  'Am': 63,
#  'Amar': 64,
#  'Ambient': 65,
#  'America': 66,
#  'AnauBava': 67,
#  'Androids': 68,
#  'Animal': 69,
#  'Anthropogenic': 70,
#  'Antonio': 71,
#  'ApnaI': 72,
#  'Apnaa': 73,
#  'Apnaanao': 74,
#  'Apnao': 75,
#  'Apple': 76,
#  'Application': 77,
#  'Aqavaa': 78,
#  'Arctic': 79,
#  'Ariel': 80,
#  'Army': 81,
#  'Arreguíन': 82,
#  'Articulated': 83,
#  'AsaavaQaanaI': 84,
#  'Asbestosis': 85,
#  'Ask': 86,
#  'Assessment': 87,
#  'Atatürk': 88,
#  'Atlantic': 89,
#  'Aum': 90,
#  'Aur': 91,
#  'Australian': 92,
#  'Available': 93,
#  'Avril': 94,
#  'Azrael': 95,
#  'B': 96,
#  'BA': 97,
#  'BASED': 98,
#  'BERLIN': 99,
#  'BG': 100,
#  'BaI': 101,
#  'BaItr': 102,
#  'BaUimaka': 103,
#  'Baa': 104,
#  'Baadshah': 105,
#  'Baaga': 106,
#  'BaaraIya': 107,
#  'Baart': 108,
#  'Baava': 109,
#  'Babli': 110,
#  'Bade': 111,
#  'Baghban': 112,
#  'Bahuguna': 113,
#  'Bananasगीत': 114,
#  'BarI': 115,
#  'Barabanki': 116,
#  'Baraha': 117,
#  'Baro': 118,
#  'Bath': 119,
#  'Best': 120,
#  'Bhoothnath': 121,
#  'Bhopal': 122,
#  'Biden': 123,
#  'Black': 124,
#  'Bldg': 125,
#  'Bodyline': 126,
#  'Bond': 127,
#  'Bonn': 128,
#  'Book': 129,
#  'Bowled': 130,
#  'Bridge': 131,
#  'Bruce': 132,
#  'Brunoआधारित': 133,
#  'Bunty': 134,
#  'Burgundyसे': 135,
#  'Bus': 136,
#  'Bush': 137,
#  'Bमोबाइल': 138,
#  'C': 139,
#  'CA': 140,
#  'CAPTCHA': 141,
#  'CCCसे': 142,
#  'CCME': 143,
#  'CFCs': 144,
#  'CFCऔर': 145,
#  'CH': 146,
#  'CO': 147,
#  'CONVERTER': 148,
#  'COPD': 149,
#  'CW': 150,
#  'CWS': 151,
#  'Calor': 152,
#  'Canada': 153,
#  'Canadian': 154,
#  'Canonकी': 155,
#  'CaoD': 156,
#  'Carbon': 157,
#  'Caughtयदि': 158,
#  'Center': 159,
#  'ChIMERA': 160,
#  'Challenge': 161,
#  'Championship': 162,
#  'Chandrashekharद्वारा': 163,
#  'Change': 164,
#  'ChangeIPPC': 165,
#  'Character': 166,
#  'Charles': 167,
#  'Charlie': 168,
#  'China': 169,
#  'Chlorofluorocarbons': 170,
#  'Chote': 171,
#  'Christ': 172,
#  'Christensen': 173,
#  'Chronic': 174,
#  'Cīnā': 175,
#  'Clean': 176,
#  'Climate': 177,
#  'Climatic': 178,
#  'Club': 179,
#  'Columbia': 180,
#  'Columbiaचालक': 181,
#  'Comedian': 182,
#  'Control': 183,
#  'Conversion': 184,
#  'Coolie': 185,
#  'Council': 186,
#  'County': 187,
#  'Cricket': 188,
#  'Cricketका': 189,
#  'Crime': 190,
#  'Cup': 191,
#  'D': 192,
#  'DARPA': 193,
#  'DARwIn': 194,
#  'DEFRA': 195,
#  'DISCOVER': 196,
#  'DMzla': 197,
#  'DOI': 198,
#  'DailyMotion': 199,
#  'Date': 200,
#  'Dateline': 201,
#  'David': 202,
#  'Deep': 203,
#  'Degreesoffreedom': 204,
#  'Department': 205,
#  'Dhvani': 206,
#  'Di': 207,
#  'Diacritic': 208,
#  'Dicionário': 209,
#  'Diego': 210,
#  'Diggles': 211,
#  'Disaster': 212,
#  'Dismissals': 213,
#  'Disneycom': 214,
#  'Donora': 215,
#  'Dowser': 216,
#  'Dream': 217,
#  'Drugs': 218,
#  'Duchy': 219,
#  'Duke': 220,
#  'Dust': 221,
#  'Dutch': 222,
#  'E': 223,
#  'ENGLISH': 224,
#  'EPA': 225,
#  'EPAका': 226,
#  'EPAने': 227,
#  'EPICA': 228,
#  'ETA': 229,
#  'ETAस्पेन': 230,
#  'Earth': 231,
#  'Edge': 232,
#  'Edward': 233,
#  'Eigil': 234,
#  'Ek': 235,
#  'El': 236,
#  'Electric': 237,
#  'Emissions': 238,
#  'Engine': 239,
#  'English': 240,
#  'Englishमें': 241,
#  'Environment': 242,
#  'EnvironmentCCME': 243,
#  'Environmental': 244,
#  'Eric': 245,
#  'Etimológico': 246,
#  'European': 247,
#  'Explorer': 248,
#  'FAQ': 249,
#  'FEV': 250,
#  'FLV': 251,
#  'FN': 252,
#  'FSJ': 253,
#  'Ferry': 254,
#  'Festival': 255,
#  'Files': 256,
#  'Film': 257,
#  'First': 258,
#  'Fix': 259,
#  'Flandersके': 260,
#  'Flash': 261,
#  'Flashऔर': 262,
#  'Flight': 263,
#  'Florida': 264,
#  'Food': 265,
#  'Foresight': 266,
#  'Forum': 267,
#  'Fossil': 268,
#  'Foundation': 269,
#  'Fourth': 270,
#  'France': 271,
#  'Francisco': 272,
#  'Francoके': 273,
#  'French': 274,
#  'Friis': 275,
#  'FriisChristensen': 276,
#  'Front': 277,
#  'Fujimoriके': 278,
#  'G': 279,
#  'GG': 280,
#  'GNU': 281,
#  'GOM': 282,
#  'GPको': 283,
#  'GSM': 284,
#  'GTD': 285,
#  'Gabriel': 286,
#  'Gaoro': 287,
#  'Gas': 288,
#  'Gateway': 289,
#  'Gawah': 290,
#  'Geographic': 291,
#  'George': 292,
#  'Ghemawat': 293,
#  'Ghosh': 294,
#  'Gillette': 295,
#  'Gillmeister': 296,
#  'Girlfriend': 297,
#  'Giver': 298,
#  'Global': 299,
#  'Godfather': 300,
#  'Gollwitzer': 301,
#  'Google': 302,
#  'Great': 303,
#  'Greenhouse': 304,
#  'Griers': 305,
#  'Groundकी': 306,
#  'Group': 307,
#  'Guard': 308,
#  'Guardian': 309,
#  'Guide': 310,
#  'H': 311,
#  'HIV': 312,
#  'HMPEG': 313,
#  'HTML': 314,
#  'HTTP': 315,
#  'HadCM': 316,
#  'Hans': 317,
#  'Hansen': 318,
#  'HarvardKyoto': 319,
#  'Heiner': 320,
#  'Henrik': 321,
#  'HiTrans': 322,
#  'Hilla': 323,
#  'Hills': 324,
#  'Hillsborough': 325,
#  'Hindi': 326,
#  'Hindustan': 327,
#  'Hirsuties': 328,
#  'Hit': 329,
#  'Holocaust': 330,
#  'However': 331,
#  'Hyper': 332,
#  'Hypomanic': 333,
#  'I': 334,
#  'IAST': 335,
#  'ICU': 336,
#  'ID': 337,
#  'IDEN': 338,
#  'II': 339,
#  'IMF': 340,
#  'INR': 341,
#  'INRके': 342,
#  'IPCC': 343,
#  'IRA': 344,
#  'ISBN': 345,
#  'ITRANS': 346,
#  'Ice': 347,
#  'Icyball': 348,
#  'Ijar': 349,
#  'In': 350,
#  'Inc': 351,
#  'Index': 352,
#  'Indexके': 353,
#  'Indian': 354,
#  'India।': 355,
#  'Indoor': 356,
#  'Informa': 357,
#  'Information': 358,
#  'Initiativeअमेरिका': 359,
#  'Insaniyat': 360,
#  'Inside': 361,
#  'Institute': 362,
#  'Intergovernmental': 363,
#  'International': 364,
#  'Internet': 365,
#  'Intimacy': 366,
#  'Irish': 367,
#  'Island': 368,
#  'Issar': 369,
#  'Jacobin': 370,
#  'James': 371,
#  'Jeeves': 372,
#  'JeongHyun': 373,
#  'Jiabao': 374,
#  'Joe': 375,
#  'John': 376,
#  'Johnson': 377,
#  'José': 378,
#  'Journalने': 379,
#  'Juarez': 380,
#  'Judson': 381,
#  'Jurassicकाल': 382,
#  'Jyotisar': 383,
#  'Jyotisarकुरुक्षेत्र': 384,
#  'Kabhi': 385,
#  'Kalpanachawla': 386,
#  'Kaojanao': 387,
#  'Kasam': 388,
#  'Kehna': 389,
#  'Kemal': 390,
#  'Keypad': 391,
#  'Khakee': 392,
#  'Khuda': 393,
#  'Khwaja': 394,
#  'Ki': 395,
#  'Korean': 396,
#  'Kotecki': 397,
#  'Köchler': 398,
#  'Kubby': 399,
#  'Kubbys': 400,
#  'Kurdistan': 401,
#  'Kyoto': 402,
#  'LAN': 403,
#  'LC': 404,
#  'LED': 405,
#  'LEMUR': 406,
#  'LHC': 407,
#  'Laboratory': 408,
#  'Laipply': 409,
#  'Lal': 410,
#  'Lanka': 411,
#  'Laqueur': 412,
#  'Larsen': 413,
#  'Last': 414,
#  'Lavigne': 415,
#  'Laws': 416,
#  'Lear': 417,
#  'Leg': 418,
#  'Legionnaires': 419,
#  'Lerner': 420,
#  'Liberation': 421,
#  'Libertarian': 422,
#  'Lim': 423,
#  'Limca': 424,
#  'Limited': 425,
#  'Line': 426,
#  'Lipikaar': 427,
#  'Liverpoolके': 428,
#  'Língua': 429,
#  'Lok': 430,
#  'Lokhandwala': 431,
#  'London': 432,
#  'Longshanksके': 433,
#  'LooKeys': 434,
#  'Lords': 435,
#  'Love': 436,
#  'Lyal': 437,
#  'Lएवेल्स्': 438,
#  'Lओअन्': 439,
#  'Lओचल्': 440,
#  'Lओन्डोन्': 441,
#  'Lओर्ड्': 442,
#  'M': 443,
#  'MAIAMBU': 444,
#  'MIT': 445,
#  'MOV': 446,
#  'MP': 447,
#  'MPEG': 448,
#  'MPऑडियो': 449,
#  'MRI': 450,
#  'MSL': 451,
#  'Machados': 452,
#  'Machine': 453,
#  'Macintosh': 454,
#  'Macromedia': 455,
#  'Mahal': 456,
#  'Maharashtra': 457,
#  'Manhattan': 458,
#  'MapMaker': 459,
#  'Marylebone': 460,
#  'May': 461,
#  'McCain': 462,
#  'Media': 463,
#  'Men': 464,
#  'Meteorological': 465,
#  'Methaneद्वारा': 466,
#  'Mga': 467,
#  'MiDyaa': 468,
#  'Michael': 469,
#  'Middle': 470,
#  'Ministers': 471,
#  'Miss': 472,
#  'Miyan': 473,
#  'Mohit': 474,
#  'Molecule': 475,
#  'Morseने': 476,
#  'Most': 477,
#  'Mozila': 478,
#  'Mrityudaata': 479,
#  'Multidecadal': 480,
#  'Muslim': 481,
#  'Mustafa': 482,
#  'Myasthenia': 483,
#  'Mऔर': 484,
#  'N': 485,
#  'NASA': 486,
#  'NBC': 487,
#  'NEWS': 488,
#  'NMT': 489,
#  'NOx': 490,
#  'NSIDC': 491,
#  'NTT': 492,
#  'Na': 493,
#  'Nagathihalli': 494,
#  'National': 495,
#  'Nations': 496,
#  'Navnirman': 497,
#  'Needlepoint': 498,
#  'Netsize': 499,
#  'New': 500,
#  'News”': 501,
#  'Nicola': 502,
#  'Niño': 503,
#  'NiñoSouthern': 504,
#  'Nobel': 505,
#  'November': 506,
#  'NueroBliss': 507,
#  'Nसीरीज': 508,
#  'O': 509,
#  'OCR': 510,
#  'Obstructed': 511,
#  'October': 512,
#  'Office': 513,
#  'Old': 514,
#  'Online': 515,
#  'Onomástico': 516,
#  'Open': 517,
#  'Organization': 518,
#  'Orleans': 519,
#  'Oscillation': 520,
#  'Oscillationघटित': 521,
#  'Out': 522,
#  'Overs': 523,
#  'Oxford': 524,
#  'P': 525,
#  'PBS': 526,
#  'PC': 527,
#  'PDA': 528,
#  'PET': 529,
#  'PHONETIC': 530,
#  'PHP': 531,
#  'PIPA': 532,
#  'PM': 533,
#  'PMR': 534,
#  'PMमुक्त': 535,
#  'PRI': 536,
#  'PROTECTIP': 537,
#  'PSI': 538,
#  'PSTN': 539,
#  'Paa': 540,
#  'Paakar': 541,
#  'Paasa': 542,
#  'Paaya': 543,
#  'Pachelbels': 544,
#  'Pakistan': 545,
#  'Palm': 546,
#  'Pan': 547,
#  'Panel': 548,
#  'PaoimaT': 549,
#  'Parabaas': 550,
#  'Parliament': 551,
#  'Particulate': 552,
#  'Party': 553,
#  'Partyपार्टी': 554,
#  'Pathपेरू': 555,
#  'Paul': 556,
#  'PayPal': 557,
#  'Pedro': 558,
#  'Pennsylvaniaमें': 559,
#  'Perception': 560,
#  'Peroxyacetyl': 561,
#  'Peter': 562,
#  'Petरूसी': 563,
#  'Phimosis': 564,
#  'Pietro': 565,
#  'Playerक़िक्क': 566,
#  'Playerकिचकिचाना': 567,
#  'Playerके': 568,
#  'Playerपर': 569,
#  'Pleistocene': 570,
#  'Point': 571,
#  'Polluter': 572,
#  'Polyglot': 573,
#  'Portuguesa': 574,
#  'Presidentजॉर्ज': 575,
#  'Prince': 576,
#  'Program': 577,
#  'Programme': 578,
#  'Protection': 579,
#  'Protocol': 580,
#  'Protocolपर': 581,
#  'Puneet': 582,
#  'Purple': 583,
#  'Q': 584,
#  'QEtelIqona': 585,
#  'QaIroQaIro': 586,
#  'QanauYa': 587,
#  'Quadro': 588,
#  'Quality': 589,
#  'QuickTimeऔररियल': 590,
#  'Quinn': 591,
#  'Qउअलिङिचटिओन्': 592,
#  'R': 593,
#  'REMINGTON': 594,
#  'RIM': 595,
#  'ROME': 596,
#  'RS': 597,
#  'Radioactive': 598,
#  'Raj': 599,
#  'Rajya': 600,
#  'Raphael': 601,
#  'RealPlayer': 602,
#  'Receiver': 603,
#  'Records': 604,
#  'Red': 605,
#  'Reduction': 606,
#  'Regional': 607,
#  'Reign': 608,
#  'Report': 609,
#  'Republican': 610,
#  'Research': 611,
#  'Resolution': 612,
#  'Richardson': 613,
#  'Rik': 614,
#  'Rishtaa': 615,
#  'Rituparno': 616,
#  'Riverside': 617,
#  'Rms': 618,
#  'Robinson': 619,
#  'RoboCup': 620,
#  'Robotic': 621,
#  'Rodखोजक': 622,
#  'Ron': 623,
#  'Rosey': 624,
#  'Rs': 625,
#  'Run': 626,
#  'Rural': 627,
#  'S': 628,
#  'SLP': 629,
#  'SMS': 630,
#  'SOPA': 631,
#  'SOx': 632,
#  'SQL': 633,
#  'SRES': 634,
#  'START_': 635,
#  'Sabha': 636,
#  'Samajwadi': 637,
#  'Samuel': 638,
#  'San': 639,
#  'Sangin': 640,
#  'Sarin': 641,
#  'Sarkar': 642,
#  'Scafetta': 643,
#  'Scenarios': 644,
#  'Schmids': 645,
#  'Schmidtपेरिस': 646,
#  'Science': 647,
#  'Sebaceous': 648,
#  'SecretaryGeneralकोफी': 649,
#  'Security': 650,
#  'Sena': 651,
#  'Sense': 652,
#  'September': 653,
#  'Serpentine': 654,
#  'Sheep”': 655,
#  'Shelf': 656,
#  'Shining': 657,
#  'Shinrikyo': 658,
#  'Shootout': 659,
#  'Shravanan': 660,
#  'Simple': 661,
#  'Singh': 662,
#  'Sixth': 663,
#  'Skeptics': 664,
#  'Slim': 665,
#  'Smog': 666,
#  'Smokeकी': 667,
#  'Soam': 668,
#  'Society': 669,
#  'Sofomo': 670,
#  'Solar': 671,
#  'Sooryavansham': 672,
#  'Source': 673,
#  'Special': 674,
#  'Spencer': 675,
#  'Springs': 676,
#  'Sri': 677,
#  'Standards': 678,
#  'StandardsCWS': 679,
#  'Star': 680,
#  'Stardust': 681,
#  'Staten': 682,
#  'States': 683,
#  'Stateके': 684,
#  'Steve': 685,
#  'Stohl': 686,
#  'Strategic': 687,
#  'Stratford': 688,
#  'Stratospheric': 689,
#  'Street': 690,
#  'Studies': 691,
#  'Study': 692,
#  'Stumped': 693,
#  'Stuxnet': 694,
#  'Suite': 695,
#  'Sulfur': 696,
#  'Sunga': 697,
#  'Sussex': 698,
#  'Svensmark': 699,
#  'Sverdlovskमाना': 700,
#  'T': 701,
#  'TD': 702,
#  'TED': 703,
#  'TEDActive': 704,
#  'TEDTalk': 705,
#  'TEDsters': 706,
#  'TETRA': 707,
#  'TO': 708,
#  'TOMDD': 709,
#  'TOOL': 710,
#  'TTS': 711,
#  'TV': 712,
#  'TYPING': 713,
#  'Taj': 714,
#  'Tanahala': 715,
#  'Technology': 716,
#  'Technologyके': 717,
#  'Temporary': 718,
#  'Terror': 719,
#  'Terrorism': 720,
#  'Terrorइस': 721,
#  'Test': 722,
#  'Texas': 723,
#  'Text': 724,
#  'Télévisions': 725,
#  'Thackeray': 726,
#  'The': 727,
#  'Third': 728,
#  'Tilly': 729,
#  'Tokyo': 730,
#  'Toronto': 731,
#  'Trek': 732,
#  'Tribe': 733,
#  'TuDo': 734,
#  'TukD': 735,
#  'Twenty': 736,
#  'Twitter': 737,
#  'Tमोबाइल': 738,
#  'UC': 739,
#  'UFOs': 740,
#  'UK': 741,
#  'UKs': 742,
#  'UNFCCC': 743,
#  'UNICODE': 744,
#  'URL': 745,
#  'US': 746,
#  'USB': 747,
#  'USGS': 748,
#  'USSRके': 749,
#  'UTC': 750,
#  'UTCअसंरूपित': 751,
#  'Uncleकी': 752,
#  'Unit': 753,
#  'United': 754,
#  'University': 755,
#  'Urban': 756,
#  'VLC': 757,
#  'VOCs': 758,
#  'Verizon': 759,
#  'Violent': 760,
#  'VmaXaIlaaa': 761,
#  'Vओचटिओनल्': 762,
#  'Vश्श्': 763,
#  'W': 764,
#  'WCDMA': 765,
#  'WGMS': 766,
#  'WMV': 767,
#  'WYSWYG': 768,
#  'Wall': 769,
#  'Wara': 770,
#  'Warren': 771,
#  'Washington': 772,
#  'Washingtonसूक्ष्म': 773,
#  'Weart': 774,
#  'Web': 775,
#  'Weekly': 776,
#  'Wen': 777,
#  'West': 778,
#  'Wide': 779,
#  'Wilderness': 780,
#  'Windows': 781,
#  'Workers': 782,
#  'World': 783,
#  'X': 784,
#  'XMLRSS': 785,
#  'XXIV': 786,
#  'XaaMiainakotna': 787,
#  'Xaasana': 788,
#  'Xaba': 789,
#  'Y': 790,
#  'YB': 791,
#  'YY': 792,
#  'YouTube': 793,
#  'Yउर': 794,
#  'Yओउर्': 795,
#  'Yय्': 796,
#  'Z': 797,
#  'ZZ': 798,
#  'ZZZZइफर': 799,
#  'ZZआदि': 800,
#  'ZZकि': 801,
#  'ZZपवित्र': 802,
#  'ZZफिर': 803,
#  'ZZमूर्तिकलागत': 804,
#  'ZZहथिनी': 805,
#  'ZZहिरत': 806,
#  'ZZहैं': 807,
#  'Zna': 808,
#  'Zअतिरिक़्त': 809,
#  'Zअधिक': 810,
#  'Zअधिकतर': 811,
#  'Zअनेक': 812,
#  'Zअपने': 813,
#  'Zअभिप्रायों': 814,
#  'Zअभियोग': 815,
#  'Zआदि': 816,
#  'Zआम': 817,
#  'Zइंकार': 818,
#  'Zइंडियन': 819,
#  'Zइंडिया': 820,
#  'Zइतिहास': 821,
#  'Zइफर': 822,
#  'Zइफस्कल': 823,
#  'Zइवशेष': 824,
#  'Zइससे': 825,
#  'Zएक': 826,
#  'Zऔर': 827,
#  'Zकथाओं': 828,
#  'Zकरती': 829,
#  'Zकरना': 830,
#  'Zकरवाया': 831,
#  'Zकरेंगे': 832,
#  'Zकवि': 833,
#  'Zकवियों': 834,
#  'Zक़्योंकि': 835,
#  'Zका': 836,
#  'Zकि': 837,
#  'Zकिया': 838,
#  'Zकिरात': 839,
#  'Zकिसी': 840,
#  'Zकी': 841,
#  'Zकुछ': 842,
#  'Zके': 843,
#  'Zको': 844,
#  'Zकोई': 845,
#  'Zक्रिया': 846,
#  'Zगतिहीन': 847,
#  'Zगरिमा': 848,
#  'Zगिरावट': 849,
#  'Zचूंकि': 850,
#  'Zजरिये': 851,
#  'Zजातियां': 852,
#  'Zजिनमें': 853,
#  'Zजिला': 854,
#  'Zजिसमें': 855,
#  'Zजीविकोपार्जन': 856,
#  'Zडिंगल': 857,
#  'Zतक': 858,
#  'Zतथा': 859,
#  'Zतमिल': 860,
#  'Zतैयार': 861,
#  'Zतो': 862,
#  'Zथा': 863,
#  'Zथापरंतु': 864,
#  'Zथी': 865,
#  'Zथे': 866,
#  'Zदक्षिण': 867,
#  'Zदिन': 868,
#  'Zदिया': 869,
#  'Zदिशाओं': 870,
#  'Zदृष्टि': 871,
#  'Zदेशभक़्ति': 872,
#  'Zदो': 873,
#  'Zनहीं': 874,
#  'Zनासिकाएं': 875,
#  'Zनिकल': 876,
#  'Zनिकलें': 877,
#  'Zनिर्वासित': 878,
#  'Zनीति': 879,
#  'Zपर': 880,
#  'Zपरशियन': 881,
#  'Zपरिणाम': 882,
#  'Zपरिवर्तन': 883,
#  'Zपरिस्थितियों': 884,
#  'Zपश्चिमाभिमुखी': 885,
#  'Zपी': 886,
#  'Zपीता': 887,
#  'Zप्रस्तुत': 888,
#  'Zप्रांतीय': 889,
#  'Zफिजूलखर्ची': 890,
#  'Zफिर': 891,
#  'Zफिरोजशाह': 892,
#  'Zफिलहाल': 893,
#  'Zबड़ी': 894,
#  'Zबड़े': 895,
#  'Zबढ़िया': 896,
#  'Zबराबर': 897,
#  'Zबहुत': 898,
#  'Zबिलियर्ड': 899,
#  'Zमंदिरों': 900,
#  'Zमलेरिया': 901,
#  'Zमस्तिष्क': 902,
#  'Zमिनट': 903,
#  'Zयह': 904,
#  'Zरचनाप्रकिया': 905,
#  'Zलागत': 906,
#  'Zलिए': 907,
#  'Zलेकिन': 908,
#  'Zवादविवाद': 909,
#  'Zविमान': 910,
#  'Zविरूद्ध': 911,
#  'Zविरोधी': 912,
#  'Zविहित': 913,
#  'Zवैज्ञानिक': 914,
#  'Zव्याख़्या': 915,
#  'Zव्यायाम': 916,
#  'Zशिक्षित': 917,
#  'Zसंविधान': 918,
#  'Zसचिवालय': 919,
#  'Zसीमित': 920,
#  'Zसे': 921,
#  'Zस्त्रियां': 922,
#  'Zस्थित': 923,
#  'Zस्थिति': 924,
#  'Zहथिनियों': 925,
#  'Zहमारे': 926,
#  'Zहमें': 927,
#  'Zहरिहर': 928,
#  'Zहाथपैरों': 929,
#  'Zहाथियों': 930,
#  'Zहालांकि': 931,
#  'Zहिदुस्तानी': 932,
#  'Zही': 933,
#  'Zहुआ': 934,
#  'Zहृदय': 935,
#  'Zहै': 936,
#  '_END': 937,
#  'a': 938,
#  'aIr': 939,
#  'aMia': 940,
#  'aMsa': 941,
#  'aPa': 942,
#  'aaik': 943,
#  'aakaaoM': 944,
#  'aakt': 945,
#  'aana': 946,
#  'aanaI': 947,
#  'absorption': 948,
#  'aca': 949,
#  'acidificationवातावरण': 950,
#  'acidएक': 951,
#  'actuators': 952,
#  'adaptजा': 953,
#  'aerosol': 954,
#  'aerosolसठंडा': 955,
#  'age': 956,
#  'agricultural': 957,
#  'agriculture': 958,
#  'air': 959,
#  'akregator': 960,
#  'alaa': 961,
#  'all': 962,
#  'am': 963,
#  'ancestor': 964,
#  'and': 965,
#  'animalउत्सर्जित': 966,
#  'animated': 967,
#  'anthraxके': 968,
#  'anthropogenic': 969,
#  'anti': 970,
#  'arMBa': 971,
#  'assaultकि': 972,
#  'asteroid': 973,
#  'asthma': 974,
#  'asthmaदवाखाने': 975,
#  'at': 976,
#  'atmospheric': 977,
#  'attack': 978,
#  'attackबच्चों': 979,
#  'automobileसे': 980,
#  'avaa': 981,
#  'average': 982,
#  'aएम': 983,
#  'baD': 984,
#  'baMdI': 985,
#  'baOzk': 986,
#  'baZ': 987,
#  'baadla': 988,
#  'baahr': 989,
#  'baasa': 990,
#  'baccaaoM': 991,
#  'backyard': 992,
#  'badlao': 993,
#  'bahut': 994,
#  'bails': 995,
#  'bajaIr': 996,
#  'ball': 997,
#  'banaI': 998,
#  'banaayao': 999,
#  'bandwidth': 1000,
#  ...}

# %%
reverse_input_char_index = dict((i, word) for word, i in input_token_index.items())
reverse_target_char_index = dict((i, word) for word, i in target_token_index.items())

# %%
df = shuffle(df)
df.head()
# Out:
#            source  ... len_hindi_words
# 94847         ted  ...              18
# 93266   indic2012  ...              14
# 103991        ted  ...              14
# 49152       tides  ...              16
# 89718         ted  ...               8
#
# [5 rows x 6 columns]

# %%
X, Y = df['english_sentenced_text'], df['hindi_sentence']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((13211,), (3303,))

# %%
X_train.to_pickle('X_train.pkl')
X_test.to_pickle('X_test.pkl')

# %%
def generate_batch(x = X_train, y=Y_train, batch_size=128):
  while True:
    for j in range(0, len(x), batch_size):
      encoder_input_data = np.zeros((batch_size, max_length_src), dtype='float32')
      decoder_input_data = np.zeros((batch_size, max_length_tar), dtype='float32')
      decoder_target_data = np.zeros((batch_size, max_length_tar, num_decoder_tokens), dtype='float32')
      for i, (input_text, target_text) in enumerate(zip(x[j:j+batch_size], y[j:j+batch_size])):
        for t, word in enumerate(input_text.split()):
          encoder_input_data[i,t] = input_token_index[word]
        for t, word in enumerate(target_text.split()):
          if t < len(target_text.split()) - 1:
            decoder_input_data[i, t] = target_token_index[word]
          if t > 0 :
            decoder_target_data[i, t-1, target_token_index[word]] = 1.
      yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %%
latent_dim = 256

# %%
encoder_inputs = Input(shape=(None,))
enc_emd = Embedding(num_encoder_tokens, latent_dim, mask_zero=True)(encoder_inputs)
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(enc_emd)

encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,))
dec_emd_layer = Embedding(num_decoder_tokens, latent_dim, mask_zero=True)
dec_emd = dec_emd_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs,_, _ = decoder_lstm(dec_emd, initial_state=encoder_states) 
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

train_samples = len(X_train)
val_samples = len(X_test)
batch_size = 128
epochs=20
max_length_src = max(df['len_english_words'])
max_length_tar = max(df['len_hindi_words'])

model.fit_generator(generator = generate_batch(X_train, Y_train, batch_size=batch_size), steps_per_epoch=train_samples//batch_size,
                    epochs = epochs, validation_data =  generate_batch(X_test, Y_test, batch_size=batch_size),
                    validation_steps = val_samples// batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/20
# 103/103 [==============================] - 55s 443ms/step - loss: 3.7861 - acc: 0.1122 - val_loss: 3.6207 - val_acc: 0.1216
# Epoch 2/20
# 103/103 [==============================] - 42s 404ms/step - loss: 3.4460 - acc: 0.1231 - val_loss: 3.5733 - val_acc: 0.1263
# Epoch 3/20
# 103/103 [==============================] - 41s 394ms/step - loss: 3.3241 - acc: 0.1322 - val_loss: 3.4751 - val_acc: 0.1358
# Epoch 4/20
# 103/103 [==============================] - 41s 397ms/step - loss: 3.1858 - acc: 0.1466 - val_loss: 3.4231 - val_acc: 0.1515
# Epoch 5/20
# 103/103 [==============================] - 41s 398ms/step - loss: 3.0760 - acc: 0.1580 - val_loss: 3.3559 - val_acc: 0.1600
# Epoch 6/20
# 103/103 [==============================] - 40s 392ms/step - loss: 2.9805 - acc: 0.1695 - val_loss: 3.3143 - val_acc: 0.1686
# Epoch 7/20
# 103/103 [==============================] - 41s 397ms/step - loss: 2.8890 - acc: 0.1795 - val_loss: 3.3088 - val_acc: 0.1734
# Epoch 8/20
# 103/103 [==============================] - 41s 397ms/step - loss: 2.8078 - acc: 0.1885 - val_loss: 3.2797 - val_acc: 0.1755
# Epoch 9/20
# 103/103 [==============================] - 41s 394ms/step - loss: 2.7303 - acc: 0.1974 - val_loss: 3.2739 - val_acc: 0.1816
# Epoch 10/20
# 103/103 [==============================] - 41s 397ms/step - loss: 2.6534 - acc: 0.2063 - val_loss: 3.2787 - val_acc: 0.1844
# Epoch 11/20
# 103/103 [==============================] - 41s 399ms/step - loss: 2.5794 - acc: 0.2158 - val_loss: 3.2440 - val_acc: 0.1884
# Epoch 12/20
# 103/103 [==============================] - 41s 394ms/step - loss: 2.5073 - acc: 0.2255 - val_loss: 3.2321 - val_acc: 0.1914
# Epoch 13/20
# 103/103 [==============================] - 41s 397ms/step - loss: 2.4408 - acc: 0.2352 - val_loss: 3.2369 - val_acc: 0.1918
# Epoch 14/20
# 103/103 [==============================] - 41s 398ms/step - loss: 2.3687 - acc: 0.2467 - val_loss: 3.2334 - val_acc: 0.1941
# Epoch 15/20
# 103/103 [==============================] - 41s 394ms/step - loss: 2.3009 - acc: 0.2575 - val_loss: 3.2260 - val_acc: 0.1952
# Epoch 16/20
# 103/103 [==============================] - 41s 397ms/step - loss: 2.2360 - acc: 0.2692 - val_loss: 3.2350 - val_acc: 0.1986
# Epoch 17/20
# 103/103 [==============================] - 40s 393ms/step - loss: 2.1691 - acc: 0.2826 - val_loss: 3.2398 - val_acc: 0.2011
# Epoch 18/20
# 103/103 [==============================] - 41s 394ms/step - loss: 2.1056 - acc: 0.2952 - val_loss: 3.2333 - val_acc: 0.2018
# Epoch 19/20
# 103/103 [==============================] - 40s 394ms/step - loss: 2.0391 - acc: 0.3094 - val_loss: 3.2406 - val_acc: 0.2002
# Epoch 20/20
# 103/103 [==============================] - 41s 395ms/step - loss: 1.9752 - acc: 0.3244 - val_loss: 3.2504 - val_acc: 0.2005

# %%
model.save_weights('NMT_weights.h5')

# %%
model.load_weights('NMT_weights.h5')

# %%
# Encode the input sequence to get the "thought vectors"
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2= dec_emd_layer(decoder_inputs) # Get the embeddings of the decoder sequence

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2) # A dense softmax layer to generate prob dist. over the target vocabulary

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %% [markdown]
# # Decode sample sequeces

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['START_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 50):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %% [markdown]
# # Evaluation on Train Dataset

# %%
train_gen = generate_batch(X_train, Y_train, batch_size = 1)
k=-1

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Hindi Translation:', Y_train[k:k+1].values[0][6:-4])
print('Predicted Hindi Translation:', decoded_sentence[:-6])
# Out:
# Input English sentence: but though powerful the king who symbolised the state did not have the right to legislate
# Actual Hindi Translation:  राजा शक्तिशाली था और राज्य का प्रतीक भी था किंतु उसे विधि निर्माण का अधिकार नहीं था
# Predicted Hindi Translation:  लेकिन इस दौरान अकबर के दौरान संसद के दौरान वे
